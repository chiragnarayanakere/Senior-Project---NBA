# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.plotly as py
import warnings
import xgboost as xgb
warnings.filterwarnings('ignore')

# %% [markdown]
# # 2008

# %%
data1213 = pd.read_csv('Downloads/results/input_files/NBA Player Stats - Regular Stats 2012-2013.csv')
data1213.drop(['Tm', 'Rk'], axis=1, inplace=True)
data1112 = pd.read_csv('Downloads/results/input_files/NBA Player Stats - Regular Stats 2011-2012.csv')
data1112.drop(['Tm', 'Rk'], axis=1, inplace=True)
data1011 = pd.read_csv('Downloads/results/input_files/NBA Player Stats - Regular Stats 2010-2011.csv')
data1011.drop(['Tm', 'Rk'], axis=1, inplace=True)
data0910 = pd.read_csv('Downloads/results/input_files/NBA Player Stats - Regular Stats 2009-2010.csv')
data0910.drop(['Tm', 'Rk'], axis=1, inplace=True)
data0809 = pd.read_csv('Downloads/results/input_files/NBA Player Stats - Regular Stats 2008-2009.csv')
data0809.drop(['Tm', 'Rk'], axis=1, inplace=True)
data0809.head()
# Out:
#                     Player Pos   Age     G   GS    MP   FG  FGA    FG%   3P  \
# 0     Alex Acker\ackeral01  SG  26.0  25.0  0.0   8.0  1.2  3.0  0.395  0.3
# 1     Alex Acker\ackeral01  SG  26.0   7.0  0.0   2.9  0.6  1.6  0.364  0.0
# 2     Alex Acker\ackeral01  SG  26.0  18.0  0.0   9.9  1.4  3.6  0.400  0.4
# 3   Hassan Adams\adamsha01  SG  24.0  12.0  0.0   4.3  0.3  1.1  0.308  0.0
# 4  Arron Afflalo\afflaar01  SG  23.0  74.0  8.0  16.7  1.8  4.1  0.437  0.6
#
#    ...    FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF  PS/G
# 0  ...  0.500  0.3  0.6  1.0  0.5  0.2  0.2  0.3  0.4   2.9
# 1  ...  0.500  0.0  0.3  0.3  0.1  0.3  0.1  0.0  0.0   1.3
# 2  ...  0.500  0.4  0.8  1.2  0.6  0.2  0.2  0.4  0.5   3.5
# 3  ...  0.500  0.1  0.5  0.6  0.1  0.1  0.1  0.3  0.3   0.9
# 4  ...  0.817  0.4  1.4  1.8  0.6  0.4  0.2  0.6  1.9   4.9
#
# [5 rows x 28 columns]

# %% [markdown]
# # College data

# %%
draft2008 = pd.read_csv('Downloads/results/input_files/2008_class_urls.csv')
draft2008.columns
college = draft2008[['Name', ' Years in College']]
draft2008
# Out:
#                      Name   Draft Class   Years in College   Season   Age  \
# 0        Anthony Randolph          2008                  1  2007-08    18
# 1         Sean Singletary          2008                  4  2007-08    22
# 2             Brook Lopez          2008                  2  2007-08    19
# 3              D.J. White          2008                  4  2007-08    21
# 4            J.R. Giddens          2008                  4  2007-08    22
# 5             Roy Hibbert          2008                  4  2007-08    21
# 6            Nathan Jawai          2008                  1  2006-07    20
# 7             George Hill          2008                  4  2007-08    21
# 8             Bill Walker          2008                  2  2007-08    20
# 9             Joey Dorsey          2008                  4  2007-08    24
# 10         Malik Hairston          2008                  4  2007-08    20
# 11          Patrick Ewing          2008                  4  2007-08    23
# 12          D.J. Augustin          2008                  2  2007-08    20
# 13             Kevin Love          2008                  1  2007-08    19
# 14          Joe Alexander          2008                  3  2007-08    21
# 15           Donte Greene          2008                  1  2007-08    19
# 16            Sonny Weems          2008                  2  2007-08    21
# 17            Robin Lopez          2008                  2  2007-08    19
# 18             Sasha Kaun          2008                  4  2007-08    22
# 19        Michael Beasley          2008                  1  2007-08    19
# 20              O.J. Mayo          2008                  1  2007-08    20
# 21      Marreese Speights          2008                  2  2007-08    20
# 22           JaVale McGee          2008                  2  2007-08    20
# 23          Ryan Anderson          2008                  2  2007-08    19
# 24            Mike Taylor          2008                  1  2006-07    21
# 25         DeAndre Jordan          2008                  1  2007-08    19
# 26           Brandon Rush          2008                  3  2007-08    22
# 27          Walter Sharpe          2008                  3  2007-08    21
# 28        Darnell Jackson          2008                  4  2007-08    22
# 29            Eric Gordon          2008                  1  2007-08    19
# 30           Kosta Koufos          2008                  1  2007-08    18
# 31           Joe Crawford          2008                  4  2007-08    21
# 32           Courtney Lee          2008                  4  2007-08    22
# 33         Mario Chalmers          2008                  3  2007-08    21
# 34  Chris Douglas-Roberts          2008                  3  2007-08    21
# 35           J.J. Hickson          2008                  1  2007-08    19
# 36          Maarty Leunen          2008                  4  2007-08    22
# 37         Darrell Arthur          2008                  2  2007-08    19
# 38           Derrick Rose          2008                  1  2007-08    19
# 39            Kyle Weaver          2008                  4  2007-08    21
# 40      Russell Westbrook          2008                  2  2007-08    19
# 41       Luc Mbah a Moute          2008                  3  2007-08    21
# 42           DeVon Hardin          2008                  4  2007-08    21
# 43         Jason Thompson          2008                  4  2007-08    21
# 44         Jerryd Bayless          2008                  1  2007-08    19
#
#        College   G      MP   FG   FGA  ...   BLK    TOV   PTS    FG%    3p%  \
# 0          LSU  31  1016.0  183   394  ...  70.0   92.0   483  0.464  0.105
# 1     VIRGINIA  33  1122.0  203   476  ...   1.0  128.0   653  0.426  0.367
# 2     STANFORD  27   831.0  184   393  ...  56.0   58.0   521  0.468  0.000
# 3      INDIANA  33  1105.0  216   357  ...  54.0   63.0   575  0.605  0.333
# 4      NMEXICO  33  1063.0  210   407  ...  39.0   73.0   537  0.516  0.333
# 5   GEORGETOWN  34   894.0  179   294  ...  75.0   57.0   454  0.609  1.000
# 6    MIDLANDCC  13   311.0   56   105  ...   NaN    NaN   148  0.533  0.000
# 7        IUPUI  32  1179.0  220   404  ...  13.0   94.0   688  0.545  0.450
# 8     KANSASST  31   846.0  181   389  ...  17.0   81.0   498  0.465  0.307
# 9      MEMPHIS  38   958.0  108   167  ...  74.0   41.0   261  0.647    NaN
# 10      OREGON  31   976.0  176   335  ...  26.0   55.0   505  0.525  0.433
# 11  GEORGETOWN  34     NaN   74   140  ...  23.0   54.0   209  0.529  0.283
# 12       TEXAS  38  1417.0  242   551  ...   0.0  105.0   731  0.439  0.381
# 13        UCLA  39  1156.0  227   406  ...  56.0   78.0   681  0.559  0.354
# 14   WVIRGINIA  36  1137.0  219   474  ...  54.0   80.0   607  0.462  0.268
# 15    SYRACUSE  35  1253.0  218   521  ...  57.0   91.0   620  0.418  0.345
# 16    ARKANSAS  34  1067.0  197   425  ...   8.0   96.0   509  0.464  0.370
# 17    STANFORD  36   883.0  140   262  ...  83.0   63.0   367  0.534  1.000
# 18      KANSAS  40     NaN  109   176  ...  49.0   32.0   284  0.619    NaN
# 19    KANSASST  33  1041.0  307   577  ...  54.0   95.0   866  0.532  0.379
# 20         USC  33  1216.0  237   536  ...  13.0  117.0   684  0.442  0.409
# 21     FLORIDA  36   874.0  216   346  ...  49.0   62.0   522  0.624    NaN
# 19  0.774    31.5     26.2     12.4      1.2
# 20  0.803    36.8     20.7      4.5      3.3
# 21  0.692    24.3     14.5      8.1      0.9
# 22  0.525    27.3     14.1      7.3      0.6
# 23  0.869    32.8     21.1      9.9      1.4
# 24  0.682    35.0     16.0      4.1      4.5
# 25  0.437    20.1      7.9      6.0      0.4
# 26  0.779    29.7     13.3      5.1      2.1
# 27  0.523    24.9     14.2      6.8      1.7
# 28  0.691    24.3     11.2      6.7      1.1
# 29  0.834    34.7     20.9      3.3      2.4
# 30  0.680    27.1     14.4      6.7      0.5
# 31  0.762    33.6     17.9      3.6      2.1
# 32  0.822    30.0     20.4      4.9      2.1
# 33  0.746    30.0     12.8      3.1      4.3
# 34  0.712    28.7     18.1      4.1      1.8
# 35  0.677    28.7     14.8      8.5      1.0
# 36  0.789     NaN     15.2      9.2      2.8
# 37  0.702    24.7     12.8      6.3      0.8
# 38  0.712    29.2     14.9      4.5      4.7
# 39  0.733    33.1     12.2      5.3      4.3
# 40  0.713    33.8     12.7      3.9      4.3
# 41  0.689    29.0      8.8      6.0      1.5
# 42  0.636     NaN      9.3      7.4      0.7
# 43  0.581    34.6     20.4     12.1      2.7
# 44  0.839    35.7     19.7      2.7      4.0
#
# [45 rows x 28 columns]

# %% [markdown]
# # Avg. of 2008-09 to 2012-13

# %%
names = list(draft2008['Name'][1:])
namenyear = draft2008[['Name', ' Years in College']][1:] 
namenyear = namenyear.sort_values('Name')
namenyear = namenyear.reset_index()
namenyear = namenyear.drop('index', 1)

                  
#------------------------------------------------------------

n1213 = []
for i in range(len(data1213['Player'])):
    for j in range(len(names)):
        if data1213['Player'][i] == names[j]:
            n1213.append(names[j])       
n1213 = list(set(n1213)) 

f1213 = pd.DataFrame(index=range(len(n1213)),columns=data1213.columns)

for i in range(len(n1213)):

    for word in f1213.columns:

         f1213[word][i] = data1213.loc[data1213['Player'] == n1213[i]][word].values[0] 
            
#------------------------------------------------------------

n1112 = []
for i in range(len(data1112['Player'])):
    for j in range(len(names)):
        if data1112['Player'][i] == names[j]:
            n1112.append(names[j])       
n1112 = list(set(n1112)) 

f1112 = pd.DataFrame(index=range(len(n1112)),columns=data1112.columns)

for i in range(len(n1112)):

    for word in f1112.columns:

         f1112[word][i] = data1112.loc[data1112['Player'] == n1112[i]][word].values[0] 

#------------------------------------------------------------

n1011 = []
for i in range(len(data1011['Player'])):
    for j in range(len(names)):
        if data1011['Player'][i] == names[j]:
            n1011.append(names[j])       
n1011 = list(set(n1011)) 

f1011 = pd.DataFrame(index=range(len(n1011)),columns=data1011.columns)

for i in range(len(n1011)):

    for word in f1011.columns:

         f1011[word][i] = data1011.loc[data1011['Player'] == n1011[i]][word].values[0] 
            
#------------------------------------------------------------

n0910 = []
for i in range(len(data0910['Player'])):
    for j in range(len(names)):
        if data0910['Player'][i] == names[j]:
            n0910.append(names[j])       
n0910 = list(set(n0910))

f0910 = pd.DataFrame(index=range(len(n0910)),columns=data0910.columns)

for i in range(len(n0910)):

    for word in f0910.columns:

         f0910[word][i] = data0910.loc[data0910['Player'] == n0910[i]][word].values[0]
            
#------------------------------------------------------------

n0809 = []
for i in range(len(data0809['Player'])):
    for j in range(len(names)):
        if data0809['Player'][i] == names[j]:
            n0809.append(names[j])       
n0809 = list(set(n0809))

f0809 = pd.DataFrame(index=range(len(n0809)),columns=data0809.columns)

for i in range(len(n0809)):

    for word in f0809.columns:

         f0809[word][i] = data0809.loc[data0809['Player'] == n0809[i]][word].values[0]
                       

final = f0809.append([f0910, f1213, f1112, f1011])
final = final.reset_index()
final.drop(['index'], axis=1, inplace=True)

final['Age']= final['Age'].astype('float64')
final['G']= final['G'].astype('float64')
final['GS']= final['GS'].astype('float64')
final['MP']= final['MP'].astype('float64')
final['FG']= final['FG'].astype('float64')
final['FGA']= final['FGA'].astype('float64')
final['FG%']= final['FG%'].astype('float64')
final['3P']= final['3P'].astype('float64')
final['3PA']= final['3PA'].astype('float64')
final['3P%']= final['3P%'].astype('float64')
final['2P']= final['2P'].astype('float64')
final['2PA']= final['2PA'].astype('float64')
final['2P%']= final['2P%'].astype('float64')
final['eFG%']= final['eFG%'].astype('float64')
final['FT']= final['FT'].astype('float64')
final['FTA']= final['FTA'].astype('float64')
final['FT%']= final['FT%'].astype('float64')
final['ORB']= final['ORB'].astype('float64')
final['DRB']= final['DRB'].astype('float64')
final['TRB']= final['TRB'].astype('float64')
final['AST']= final['AST'].astype('float64')
final['STL']= final['STL'].astype('float64')
final['BLK']= final['BLK'].astype('float64')
final['TOV']= final['TOV'].astype('float64')
final['PF']= final['PF'].astype('float64')
final['PS/G']= final['PS/G'].astype('float64')

finaldata = final.groupby('Player', as_index=False).mean()
finaldata.insert(1, "Years in College", namenyear[' Years in College']) 
finaldata['Years in College'] = 0

finaldata = finaldata[['Player', 'Years in College', 'Age', 'G', 'GS', 'MP', 'FG', 'FGA',
       'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA',
       'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PS/G']]

# %%
x = []
for i in range(len(finaldata['Player'])):
    for j in range(len(n1213)):
        if finaldata['Player'][i] == n1213[j]:
            x.append(n1213[j])       
f = list(set(x))

test = finaldata

test = test[test['Player'].isin(f)].reset_index().drop('index', 1)

combined = college
combined = combined.sort_values('Name').reset_index().drop('index', 1)
combined['Player'] = test['Player']
combined['check'] = combined['Name'].isin(combined['Player'])
combined = combined[combined.check == True]
combined = combined[['Name', ' Years in College']]
years = list(combined[' Years in College'])
test['Years in College'] = years

test
#test.to_csv('Desktop/finaldata/2008draft.csv', sep='\t', encoding='utf-8')
# Out:
#                    Player  Years in College   Age          G         GS  \
# 0            Brandon Rush                 3  26.0  44.666667   7.333333
# 1             Brook Lopez                 2  23.0  53.666667  53.666667
# 2   Chris Douglas-Roberts                 3  25.0  25.000000   6.000000
# 3            Courtney Lee                 4  26.0  72.333333  22.000000
# 4           D.J. Augustin                 2  24.0  68.666667  44.333333
# 23  34.966667  8.166667  18.300000  0.445667  0.833333  ...  0.821667
# 24  28.466667  4.900000  11.466667  0.430667  2.466667  ...  0.844333
#
#          ORB        DRB        TRB       AST       STL       BLK       TOV  \
# 0   0.333333   2.200000   2.533333  1.100000  0.366667  0.466667  1.166667
# 1   2.266667   3.200000   5.500000  1.233333  0.400000  1.466667  1.700000
# 2   0.100000   1.300000   1.400000  0.900000  0.500000  0.150000  0.500000
# 3   0.466667   2.100000   2.566667  1.500000  1.000000  0.300000  1.000000
# 4   0.433333   1.666667   2.066667  4.900000  0.633333  0.000000  1.700000
# 5   0.700000   1.966667   2.700000  0.500000  0.233333  0.433333  0.400000
# 6   1.300000   2.250000   3.600000  0.650000  0.550000  0.700000  0.900000
# 7   2.766667   4.833333   7.566667  0.366667  0.533333  1.733333  1.200000
# 8   0.400000   2.100000   2.500000  3.700000  1.266667  0.300000  2.733333
# 9   0.500000   2.600000   3.100000  3.366667  0.933333  0.300000  1.266667
# 10  2.833333   5.566667   8.433333  1.000000  0.600000  0.633333  1.766667
# 11  2.500000   4.366667   6.866667  0.433333  0.500000  2.200000  1.266667
# 12  2.200000   4.333333   6.566667  1.133333  0.566667  0.666667  1.200000
# 13  0.333333   1.933333   2.200000  3.600000  0.666667  0.133333  1.666667
# 14  4.066667  10.100000  14.166667  2.266667  0.733333  0.466667  2.200000
# 15  1.900000   3.066667   4.966667  0.266667  0.400000  0.900000  0.666667
# 16  1.800000   3.200000   5.000000  0.833333  0.833333  0.366667  1.033333
# 17  0.233333   2.100000   2.333333  3.166667  1.366667  0.166667  1.666667
# 18  1.666667   3.100000   4.800000  0.633333  0.266667  0.500000  0.933333
# 19  1.033333   3.566667   4.600000  1.566667  0.500000  0.533333  2.100000
# 20  0.466667   2.566667   3.033333  3.000000  1.066667  0.333333  1.966667
# 21  1.800000   2.266667   4.033333  0.400000  0.333333  1.066667  0.900000
# 22  3.066667   5.133333   8.200000  1.700000  0.466667  2.133333  2.133333
# 23  1.466667   3.366667   4.800000  7.033333  1.800000  0.333333  3.600000
# 24  2.700000   3.833333   6.533333  0.966667  0.600000  0.466667  0.966667
#
#           PF       PS/G
# 0   1.700000   8.633333
# 1   2.200000  19.666667
# 2   1.200000   5.050000
# 3   1.633333   9.166667
# 4   1.366667  10.066667
# 5   1.200000   4.966667
# 6   2.500000   7.600000
# 7   2.800000   7.766667
# 8   2.033333  19.966667
# 9   1.933333  11.800000
# 10  2.100000  11.633333
# 11  2.633333  10.166667
# 12  2.633333   9.600000
# 13  2.166667   9.766667
# 14  2.233333  21.500000
# 15  2.066667   5.566667
# 16  1.966667   7.033333
# 17  2.466667   8.266667
# 18  2.200000   7.500000
# 19  2.066667  13.600000
# 20  2.100000  13.066667
# 21  2.033333   7.700000
# 22  3.233333  12.466667
# 23  2.333333  22.900000
# 24  2.233333  14.300000
#
# [25 rows x 28 columns]
