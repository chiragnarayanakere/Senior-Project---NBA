# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.plotly as py
import warnings
import xgboost as xgb
warnings.filterwarnings('ignore')

# %% [markdown]
# # 2008

# %%
data1213 = pd.read_csv('Downloads/NBA Player Stats - Regular Stats 2012-2013.csv')
data1213.drop(['Tm', 'Rk'], axis=1, inplace=True)
data1112 = pd.read_csv('Downloads/NBA Player Stats - Regular Stats 2011-2012.csv')
data1112.drop(['Tm', 'Rk'], axis=1, inplace=True)
data1011 = pd.read_csv('Downloads/NBA Player Stats - Regular Stats 2010-2011.csv')
data1011.drop(['Tm', 'Rk'], axis=1, inplace=True)
data0910 = pd.read_csv('Downloads/NBA Player Stats - Regular Stats 2009-2010.csv')
data0910.drop(['Tm', 'Rk'], axis=1, inplace=True)
data0809 = pd.read_csv('Downloads/NBA Player Stats - Regular Stats 2008-2009.csv')
data0809.drop(['Tm', 'Rk'], axis=1, inplace=True)
data0809.head()
# Out:
#                     Player Pos   Age     G   GS    MP   FG  FGA    FG%   3P  \
# 0     Alex Acker\ackeral01  SG  26.0  25.0  0.0   8.0  1.2  3.0  0.395  0.3
# 1     Alex Acker\ackeral01  SG  26.0   7.0  0.0   2.9  0.6  1.6  0.364  0.0
# 2     Alex Acker\ackeral01  SG  26.0  18.0  0.0   9.9  1.4  3.6  0.400  0.4
# 3   Hassan Adams\adamsha01  SG  24.0  12.0  0.0   4.3  0.3  1.1  0.308  0.0
# 4  Arron Afflalo\afflaar01  SG  23.0  74.0  8.0  16.7  1.8  4.1  0.437  0.6
#
#    ...     FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF  PS/G
# 0  ...   0.500  0.3  0.6  1.0  0.5  0.2  0.2  0.3  0.4   2.9
# 1  ...   0.500  0.0  0.3  0.3  0.1  0.3  0.1  0.0  0.0   1.3
# 2  ...   0.500  0.4  0.8  1.2  0.6  0.2  0.2  0.4  0.5   3.5
# 3  ...   0.500  0.1  0.5  0.6  0.1  0.1  0.1  0.3  0.3   0.9
# 4  ...   0.817  0.4  1.4  1.8  0.6  0.4  0.2  0.6  1.9   4.9
#
# [5 rows x 28 columns]

# %% [markdown]
# # College data

# %%
draft2008 = pd.read_csv('Downloads/csvfiles/2008_class_urls.csv')
draft2008.columns
draft2008
# Out:
#                      Name   Draft Class   Years in College   Season   Age  \
# 0        Anthony Randolph          2008                  1  2007-08    18
# 1         Sean Singletary          2008                  4  2007-08    22
# 2             Brook Lopez          2008                  2  2007-08    19
# 3              D.J. White          2008                  4  2007-08    21
# 4            J.R. Giddens          2008                  4  2007-08    22
# 5             Roy Hibbert          2008                  4  2007-08    21
# 6            Nathan Jawai          2008                  1  2006-07    20
# 7             George Hill          2008                  4  2007-08    21
# 8             Bill Walker          2008                  2  2007-08    20
# 9             Joey Dorsey          2008                  4  2007-08    24
# 10         Malik Hairston          2008                  4  2007-08    20
# 11          Patrick Ewing          2008                  4  2007-08    23
# 12          D.J. Augustin          2008                  2  2007-08    20
# 13             Kevin Love          2008                  1  2007-08    19
# 14          Joe Alexander          2008                  3  2007-08    21
# 15           Donte Greene          2008                  1  2007-08    19
# 16            Sonny Weems          2008                  2  2007-08    21
# 17            Robin Lopez          2008                  2  2007-08    19
# 18             Sasha Kaun          2008                  4  2007-08    22
# 19        Michael Beasley          2008                  1  2007-08    19
# 20              O.J. Mayo          2008                  1  2007-08    20
# 21      Marreese Speights          2008                  2  2007-08    20
# 22           JaVale McGee          2008                  2  2007-08    20
# 23          Ryan Anderson          2008                  2  2007-08    19
# 24            Mike Taylor          2008                  1  2006-07    21
# 25         DeAndre Jordan          2008                  1  2007-08    19
# 26           Brandon Rush          2008                  3  2007-08    22
# 27          Walter Sharpe          2008                  3  2007-08    21
# 28        Darnell Jackson          2008                  4  2007-08    22
# 29            Eric Gordon          2008                  1  2007-08    19
# 30           Kosta Koufos          2008                  1  2007-08    18
# 31           Joe Crawford          2008                  4  2007-08    21
# 32           Courtney Lee          2008                  4  2007-08    22
# 33         Mario Chalmers          2008                  3  2007-08    21
# 34  Chris Douglas-Roberts          2008                  3  2007-08    21
# 35           J.J. Hickson          2008                  1  2007-08    19
# 36          Maarty Leunen          2008                  4  2007-08    22
# 37         Darrell Arthur          2008                  2  2007-08    19
# 38           Derrick Rose          2008                  1  2007-08    19
# 39            Kyle Weaver          2008                  4  2007-08    21
# 40      Russell Westbrook          2008                  2  2007-08    19
# 41       Luc Mbah a Moute          2008                  3  2007-08    21
# 42           DeVon Hardin          2008                  4  2007-08    21
# 43         Jason Thompson          2008                  4  2007-08    21
# 44         Jerryd Bayless          2008                  1  2007-08    19
#
#        College   G      MP   FG   FGA   ...      BLK    TOV   PTS    FG%  \
# 0          LSU  31  1016.0  183   394   ...     70.0   92.0   483  0.464
# 1     VIRGINIA  33  1122.0  203   476   ...      1.0  128.0   653  0.426
# 2     STANFORD  27   831.0  184   393   ...     56.0   58.0   521  0.468
# 3      INDIANA  33  1105.0  216   357   ...     54.0   63.0   575  0.605
# 4      NMEXICO  33  1063.0  210   407   ...     39.0   73.0   537  0.516
# 5   GEORGETOWN  34   894.0  179   294   ...     75.0   57.0   454  0.609
# 6    MIDLANDCC  13   311.0   56   105   ...      NaN    NaN   148  0.533
# 7        IUPUI  32  1179.0  220   404   ...     13.0   94.0   688  0.545
# 8     KANSASST  31   846.0  181   389   ...     17.0   81.0   498  0.465
# 9      MEMPHIS  38   958.0  108   167   ...     74.0   41.0   261  0.647
# 10      OREGON  31   976.0  176   335   ...     26.0   55.0   505  0.525
# 11  GEORGETOWN  34     NaN   74   140   ...     23.0   54.0   209  0.529
# 12       TEXAS  38  1417.0  242   551   ...      0.0  105.0   731  0.439
# 13        UCLA  39  1156.0  227   406   ...     56.0   78.0   681  0.559
# 14   WVIRGINIA  36  1137.0  219   474   ...     54.0   80.0   607  0.462
# 15    SYRACUSE  35  1253.0  218   521   ...     57.0   91.0   620  0.418
# 16    ARKANSAS  34  1067.0  197   425   ...      8.0   96.0   509  0.464
# 17    STANFORD  36   883.0  140   262   ...     83.0   63.0   367  0.534
# 18      KANSAS  40     NaN  109   176   ...     49.0   32.0   284  0.619
# 19    KANSASST  33  1041.0  307   577   ...     54.0   95.0   866  0.532
# 20         USC  33  1216.0  237   536   ...     13.0  117.0   684  0.442
# 21     FLORIDA  36   874.0  216   346   ...     49.0   62.0   522  0.624
# 22      NEVADA  33   902.0  189   357   ...     92.0   80.0   466  0.529
# 23  CALIFORNIA  33  1082.0  230   469   ...     18.0   74.0   697  0.490
# 24      IOWAST  31  1086.0  165   439   ...      3.0    NaN   495  0.376
# 25     TEXASAM  35   703.0  113   183   ...     44.0   57.0   278  0.617
# 26      KANSAS  38  1127.0  180   414   ...     32.0   69.0   507  0.435
# 27         UAB  12   299.0   68   130   ...     22.0   34.0   170  0.523
# 28      KANSAS  40   971.0  171   273   ...     19.0   51.0   447  0.626
# 29     INDIANA  32  1110.0  184   425   ...     20.0  115.0   669  0.433
# 30      OHIOST  37  1003.0  222   437   ...     67.0   55.0   534  0.508
# 31    KENTUCKY  30  1009.0  188   401   ...      5.0   83.0   538  0.469
# 32   WKENTUCKY  36  1079.0  259   543   ...     28.0   84.0   735  0.477
# 33      KANSAS  39  1170.0  164   318   ...     23.0   75.0   498  0.516
# 34     MEMPHIS  40  1147.0  259   479   ...     18.0   83.0   724  0.541
# 35     NCSTATE  31   890.0  163   276   ...     47.0   83.0   458  0.591
# 36      OREGON  32     NaN  157   281   ...     11.0   50.0   485  0.559
# 37      KANSAS  40   989.0  214   394   ...     53.0   75.0   510  0.543
# 38     MEMPHIS  40  1168.0  208   436   ...     15.0  107.0   597  0.477
# 39      WASHST  35  1159.0  138   298   ...     25.0   97.0   426  0.463
# 40        UCLA  39  1318.0  182   391   ...      7.0   96.0   497  0.465
# 41        UCLA  33   958.0  117   245   ...     15.0   62.0   290  0.478
# 42  CALIFORNIA  30     NaN   98   177   ...     37.0   43.0   280  0.554
# 43       RIDER  34  1177.0  275   491   ...     91.0   99.0   694  0.560
# 44     ARIZONA  30  1072.0  173   378   ...      3.0   89.0   592  0.458
#
#       3p%    FT%   PG_MP   PG_PTS   PG_TRB   PG_AST
# 0   0.105  0.693    32.8     15.6      8.5      1.2
# 1   0.367  0.851    34.0     19.8      3.8      6.1
# 2   0.000  0.789    30.8     19.3      8.2      1.4
# 3   0.333  0.689    33.5     17.4     10.3      0.8
# 4   0.333  0.586    32.2     16.3      8.8      3.1
# 5   1.000  0.646    26.3     13.4      6.4      1.9
# 6   0.000  0.655    23.9     11.4      5.8      0.9
# 7   0.450  0.812    36.8     21.5      6.8      4.3
# 8   0.307  0.737    27.3     16.1      6.3      1.9
# 9     NaN  0.378    25.2      6.9      9.5      0.5
# 10  0.433  0.732    31.5     16.3      4.8      2.1
# 11  0.283  0.658     NaN      6.1      4.2      1.8
# 12  0.381  0.783    37.3     19.2      2.9      5.8
# 13  0.354  0.767    29.6     17.5     10.6      1.9
# 14  0.268  0.814    31.6     16.9      6.4      2.4
# 15  0.345  0.707    35.8     17.7      7.2      2.0
# 16  0.370  0.803    31.4     15.0      4.5      2.6
# 17  1.000  0.652    24.5     10.2      5.7      0.6
# 18    NaN  0.541     NaN      7.1      3.9      0.3
# 19  0.379  0.774    31.5     26.2     12.4      1.2
# 20  0.409  0.803    36.8     20.7      4.5      3.3
# 21    NaN  0.692    24.3     14.5      8.1      0.9
# 22  0.333  0.525    27.3     14.1      7.3      0.6
# 23  0.410  0.869    32.8     21.1      9.9      1.4
# 24  0.360  0.682    35.0     16.0      4.1      4.5
# 25    NaN  0.437    20.1      7.9      6.0      0.4
# 26  0.419  0.779    29.7     13.3      5.1      2.1
# 27  0.000  0.523    24.9     14.2      6.8      1.7
# 28  0.333  0.691    24.3     11.2      6.7      1.1
# 29  0.337  0.834    34.7     20.9      3.3      2.4
# 30  0.349  0.680    27.1     14.4      6.7      0.5
# 31  0.364  0.762    33.6     17.9      3.6      2.1
# 32  0.397  0.822    30.0     20.4      4.9      2.1
# 33  0.468  0.746    30.0     12.8      3.1      4.3
# 34  0.413  0.712    28.7     18.1      4.1      1.8
# 35  0.000  0.677    28.7     14.8      8.5      1.0
# 36  0.492  0.789     NaN     15.2      9.2      2.8
# 37  0.167  0.702    24.7     12.8      6.3      0.8
# 38  0.337  0.712    29.2     14.9      4.5      4.7
# 39  0.364  0.733    33.1     12.2      5.3      4.3
# 40  0.338  0.713    33.8     12.7      3.9      4.3
# 41  0.200  0.689    29.0      8.8      6.0      1.5
# 42    NaN  0.636     NaN      9.3      7.4      0.7
# 43  0.324  0.581    34.6     20.4     12.1      2.7
# 44  0.407  0.839    35.7     19.7      2.7      4.0
#
# [45 rows x 28 columns]

# %% [markdown]
# # Avg. of 2008-09 to 2012-13

# %%
names = list(draft2008['Name'][1:])
namenyear = draft2008[['Name', ' Years in College']][1:] 
namenyear = namenyear.sort_values('Name')
namenyear = namenyear.reset_index()
namenyear = namenyear.drop('index', 1)

                  
#------------------------------------------------------------

n1213 = []
for i in range(len(data1213['Player'])):
    for j in range(len(names)):
        if data1213['Player'][i] == names[j]:
            n1213.append(names[j])       
n1213 = list(set(n1213)) 

f1213 = pd.DataFrame(index=range(len(n1213)),columns=data1213.columns)

for i in range(len(n1213)):

    for word in f1213.columns:

         f1213[word][i] = data1213.loc[data1213['Player'] == n1213[i]][word].values[0] 
            
#------------------------------------------------------------

n1112 = []
for i in range(len(data1112['Player'])):
    for j in range(len(names)):
        if data1112['Player'][i] == names[j]:
            n1112.append(names[j])       
n1112 = list(set(n1112)) 

f1112 = pd.DataFrame(index=range(len(n1112)),columns=data1112.columns)

for i in range(len(n1112)):

    for word in f1112.columns:

         f1112[word][i] = data1112.loc[data1112['Player'] == n1112[i]][word].values[0] 

#------------------------------------------------------------

n1011 = []
for i in range(len(data1011['Player'])):
    for j in range(len(names)):
        if data1011['Player'][i] == names[j]:
            n1011.append(names[j])       
n1011 = list(set(n1011)) 

f1011 = pd.DataFrame(index=range(len(n1011)),columns=data1011.columns)

for i in range(len(n1011)):

    for word in f1011.columns:

         f1011[word][i] = data1011.loc[data1011['Player'] == n1011[i]][word].values[0] 
            
#------------------------------------------------------------

n0910 = []
for i in range(len(data0910['Player'])):
    for j in range(len(names)):
        if data0910['Player'][i] == names[j]:
            n0910.append(names[j])       
n0910 = list(set(n0910))

f0910 = pd.DataFrame(index=range(len(n0910)),columns=data0910.columns)

for i in range(len(n0910)):

    for word in f0910.columns:

         f0910[word][i] = data0910.loc[data0910['Player'] == n0910[i]][word].values[0]
            
#------------------------------------------------------------

n0809 = []
for i in range(len(data0809['Player'])):
    for j in range(len(names)):
        if data0809['Player'][i] == names[j]:
            n0809.append(names[j])       
n0809 = list(set(n0809))

f0809 = pd.DataFrame(index=range(len(n0809)),columns=data0809.columns)

for i in range(len(n0809)):

    for word in f0809.columns:

         f0809[word][i] = data0809.loc[data0809['Player'] == n0809[i]][word].values[0]
                       

final = f0809.append([f0910, f1213, f1112, f1011])
final = final.reset_index()
final.drop(['index'], axis=1, inplace=True)

final['Age']= final['Age'].astype('float64')
final['G']= final['G'].astype('float64')
final['GS']= final['GS'].astype('float64')
final['MP']= final['MP'].astype('float64')
final['FG']= final['FG'].astype('float64')
final['FGA']= final['FGA'].astype('float64')
final['FG%']= final['FG%'].astype('float64')
final['3P']= final['3P'].astype('float64')
final['3PA']= final['3PA'].astype('float64')
final['3P%']= final['3P%'].astype('float64')
final['2P']= final['2P'].astype('float64')
final['2PA']= final['2PA'].astype('float64')
final['2P%']= final['2P%'].astype('float64')
final['eFG%']= final['eFG%'].astype('float64')
final['FT']= final['FT'].astype('float64')
final['FTA']= final['FTA'].astype('float64')
final['FT%']= final['FT%'].astype('float64')
final['ORB']= final['ORB'].astype('float64')
final['DRB']= final['DRB'].astype('float64')
final['TRB']= final['TRB'].astype('float64')
final['AST']= final['AST'].astype('float64')
final['STL']= final['STL'].astype('float64')
final['BLK']= final['BLK'].astype('float64')
final['TOV']= final['TOV'].astype('float64')
final['PF']= final['PF'].astype('float64')
final['PS/G']= final['PS/G'].astype('float64')

finaldata = final.groupby('Player', as_index=False).mean()
finaldata.insert(1, "Years in College", namenyear[' Years in College']) 
finaldata['Years in College'] = 0

finaldata = finaldata[['Player', 'Years in College', 'Age', 'G', 'GS', 'MP', 'FG', 'FGA',
       'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA',
       'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PS/G']]

# %%
x = []
for i in range(len(finaldata['Player'])):
    for j in range(len(n1213)):
        if finaldata['Player'][i] == n1213[j]:
            x.append(n1213[j])       
f = list(set(x))

test = finaldata

test = test[test['Player'].isin(f)].reset_index().drop('index', 1)

test.to_csv('Desktop/finaldata/2008draft.csv', sep='\t', encoding='utf-8')
test
# Out:
#                    Player  Years in College        Age      G         GS  \
# 0            Brandon Rush                 0  26.500000  43.00   5.500000
# 1             Brook Lopez                 0  23.500000  44.50  44.500000
# 2   Chris Douglas-Roberts                 0  25.666667  33.00   6.666667
# 3            Courtney Lee                 0  26.500000  74.00  28.250000
# 4           D.J. Augustin                 0  24.500000  69.25  35.500000
# 5              D.J. White                 0  25.500000  29.75   2.750000
# 6          Darrell Arthur                 0  23.666667  69.00   4.333333
# 7          DeAndre Jordan                 0  23.500000  77.50  74.000000
# 8             Eric Gordon                 0  23.500000  42.75  42.250000
# 9             George Hill                 0  25.500000  69.50  41.500000
# 10           J.J. Hickson                 0  23.500000  70.75  54.250000
# 11           JaVale McGee                 0  24.500000  56.00  31.250000
# 12         Jason Thompson                 0  25.500000  75.75  57.000000
# 13         Jerryd Bayless                 0  23.500000  63.50  12.000000
# 14             Kevin Love                 0  23.500000  55.75  55.750000
# 15           Kosta Koufos                 0  22.500000  64.75  32.250000
# 16       Luc Mbah a Moute                 0  25.500000  61.00  31.500000
# 17         Mario Chalmers                 0  25.500000  71.00  60.500000
# 18      Marreese Speights                 0  24.500000  70.50  15.250000
# 19        Michael Beasley                 0  23.500000  62.50  25.500000
# 20              O.J. Mayo                 0  24.500000  67.75  30.500000
# 21            Robin Lopez                 0  23.500000  73.75  55.000000
# 22            Roy Hibbert                 0  25.500000  76.50  76.250000
# 23      Russell Westbrook                 0  23.500000  69.00  69.000000
# 24          Ryan Anderson                 0  23.500000  57.00  27.750000
#
#            MP        FG        FGA       FG%        3P    ...           FT%  \
# 0   19.025000  2.650000   5.450000  0.480500  0.825000    ...      0.703750
# 1   31.050000  7.700000  14.925000  0.517500  0.000000    ...      0.746750
# 2   17.100000  1.933333   4.533333  0.408667  0.433333    ...      0.778667
# 3   25.375000  3.575000   7.925000  0.454000  1.000000    ...      0.840750
# 4   26.575000  3.575000   8.950000  0.389250  1.375000    ...      0.876000
# 5   11.425000  1.600000   3.300000  0.380500  0.000000    ...      0.660000
# 6   17.866667  3.000000   6.633333  0.447667  0.166667    ...      0.795000
# 7   28.075000  3.500000   5.375000  0.659250  0.000000    ...      0.447750
# 8   33.575000  6.450000  14.800000  0.434500  1.475000    ...      0.801500
# 9   30.075000  3.975000   8.875000  0.445000  1.275000    ...      0.816250
# 10  26.775000  4.700000   9.450000  0.498750  0.000000    ...      0.627750
# 11  21.725000  4.100000   7.725000  0.532000  0.000000    ...      0.658750
# 12  25.400000  3.750000   7.275000  0.512500  0.000000    ...      0.620000
# 13  22.325000  3.400000   8.150000  0.416750  1.025000    ...      0.822750
# 14  36.350000  7.350000  17.125000  0.431750  1.675000    ...      0.799750
# 15  16.125000  2.550000   4.750000  0.532000  0.000000    ...      0.590250
# 16  22.150000  2.400000   5.250000  0.456250  0.075000    ...      0.651500
# 17  26.950000  3.025000   6.975000  0.432500  1.400000    ...      0.800000
# 18  15.700000  2.950000   6.400000  0.458500  0.025000    ...      0.779000
# 19  22.800000  4.925000  11.100000  0.449750  0.650000    ...      0.728250
# 20  28.625000  4.675000  11.200000  0.417750  1.550000    ...      0.803250
# 21  21.625000  3.400000   6.550000  0.511750  0.000000    ...      0.762500
# 22  28.975000  4.800000  10.375000  0.461250  0.000000    ...      0.741750
# 23  33.900000  8.000000  18.025000  0.443500  1.000000    ...      0.822750
# 24  30.375000  5.425000  12.625000  0.432500  2.600000    ...      0.871250
#
#          ORB       DRB        TRB       AST       STL    BLK       TOV  \
# 0   0.275000  1.900000   2.200000  0.975000  0.300000  0.400  1.000000
# 1   2.275000  3.325000   5.625000  1.150000  0.425000  1.550  1.675000
# 2   0.166667  1.566667   1.733333  0.933333  0.533333  0.200  0.566667
# 3   0.450000  2.075000   2.525000  1.500000  0.950000  0.325  0.975000
# 4   0.375000  1.650000   2.000000  4.775000  0.650000  0.000  1.725000
# 5   0.525000  1.725000   2.275000  0.375000  0.300000  0.325  0.300000
# 6   1.133333  2.266667   3.433333  0.733333  0.566667  0.700  0.900000
# 7   3.075000  6.000000   9.075000  0.500000  0.650000  1.925  1.275000
# 8   0.425000  2.100000   2.525000  3.600000  1.250000  0.275  2.575000
# 9   0.550000  2.700000   3.250000  3.400000  0.950000  0.300  1.250000
# 10  2.875000  5.725000   8.625000  1.100000  0.625000  0.650  1.800000
# 11  2.375000  3.625000   6.000000  0.425000  0.425000  2.000  1.350000
# 12  2.125000  4.400000   6.525000  1.000000  0.525000  0.675  1.200000
# 13  0.325000  1.875000   2.150000  3.375000  0.700000  0.125  1.525000
# 14  3.775000  9.975000  13.750000  2.800000  0.750000  0.475  2.275000
# 15  1.925000  3.100000   5.025000  0.325000  0.400000  0.900  0.700000
# 16  1.575000  2.750000   4.325000  0.775000  0.750000  0.325  0.925000
# 17  0.325000  2.175000   2.475000  3.600000  1.425000  0.175  1.800000
# 18  1.575000  2.925000   4.525000  0.575000  0.225000  0.475  0.900000
# 19  0.925000  3.325000   4.225000  1.375000  0.475000  0.500  1.825000
# 20  0.475000  2.400000   2.875000  2.800000  0.925000  0.325  1.925000
# 21  2.350000  2.850000   5.150000  0.525000  0.325000  1.225  0.925000
# 22  2.925000  4.875000   7.800000  1.550000  0.450000  2.150  2.050000
# 23  1.400000  3.650000   5.025000  7.000000  1.825000  0.300  3.650000
# 24  2.775000  3.750000   6.525000  0.925000  0.575000  0.425  0.950000
#
#           PF       PS/G
# 0   1.475000   7.000000
# 1   2.425000  19.925000
# 2   1.200000   5.666667
# 3   1.625000   9.275000
# 4   1.550000  10.825000
# 5   1.025000   3.725000
# 6   2.566667   7.033333
# 7   2.900000   8.425000
# 8   1.975000  18.825000
# 9   1.975000  11.425000
# 10  2.225000  11.675000
# 11  2.775000   9.375000
# 12  2.750000   8.975000
# 13  2.175000   9.650000
# 14  2.125000  22.650000
# 15  2.125000   5.775000
# 16  1.750000   6.150000
# 17  2.575000   8.650000
# 18  2.125000   7.225000
# 19  1.975000  12.175000
# 20  2.100000  12.725000
# 21  2.125000   8.550000
# 22  3.250000  12.050000
# 23  2.325000  22.625000
# 24  2.200000  15.675000
#
# [25 rows x 28 columns]
