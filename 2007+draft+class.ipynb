# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.plotly as py
import warnings
import xgboost as xgb
warnings.filterwarnings('ignore')

# %% [markdown]
# # 2007

# %%
data1112 = pd.read_csv('Downloads/NBA Player Stats - Regular Stats 2011-2012.csv')
data1112.drop(['Tm', 'Rk'], axis=1, inplace=True)
data1011 = pd.read_csv('Downloads/NBA Player Stats - Regular Stats 2010-2011.csv')
data1011.drop(['Tm', 'Rk'], axis=1, inplace=True)
data0910 = pd.read_csv('Downloads/NBA Player Stats - Regular Stats 2009-2010.csv')
data0910.drop(['Tm', 'Rk'], axis=1, inplace=True)
data0809 = pd.read_csv('Downloads/NBA Player Stats - Regular Stats 2008-2009.csv')
data0809.drop(['Tm', 'Rk'], axis=1, inplace=True)
data0708 = pd.read_csv('Downloads/NBA Player Stats - Regular Stats 2007-2008.csv')
data0708.drop(['Tm', 'Rk'], axis=1, inplace=True)
data0708.head()
# Out:
#                           Player Pos   Age     G   GS    MP   FG  FGA    FG%  \
# 0  Shareef Abdur-Rahim\abdursh01  PF  31.0   6.0  0.0   8.5  0.5  2.3  0.214
# 1        Arron Afflalo\afflaar01  SG  22.0  75.0  9.0  12.9  1.3  3.2  0.411
# 2          Maurice Ager\agerma01  SG  23.0  26.0  3.0   6.3  0.8  2.5  0.323
# 3          Maurice Ager\agerma01  SG  23.0  12.0  3.0   6.4  0.4  2.3  0.185
# 4          Maurice Ager\agerma01  SG  23.0  14.0  0.0   6.3  1.1  2.7  0.421
#
#     3P  ...     FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF  PS/G
# 0  0.0  ...   1.000  1.0  0.7  1.7  0.7  0.2  0.0  0.2  1.5   1.7
# 1  0.1  ...   0.782  0.5  1.3  1.8  0.7  0.4  0.1  0.5  1.1   3.7
# 2  0.1  ...   0.500  0.2  0.3  0.5  0.3  0.0  0.0  0.2  0.7   2.0
# 3  0.0  ...   0.833  0.1  0.3  0.3  0.3  0.0  0.1  0.3  0.9   1.3
# 4  0.2  ...   0.167  0.2  0.4  0.6  0.3  0.0  0.0  0.2  0.4   2.6
#
# [5 rows x 28 columns]

# %% [markdown]
# # College data

# %%
draft2007 = pd.read_csv('Downloads/csvfiles/2007_class_urls.csv')
draft2007.columns
draft2007
# Out:
#                   Name   Draft Class   Years in College   Season   Age  \
# 0           Jeff Green          2007                  3  2006-07    20
# 1          Al Thornton          2007                  4  2006-07    23
# 2          Joakim Noah          2007                  3  2006-07    21
# 3   Javaris Crittenton          2007                  1  2006-07    19
# 4       Josh McRoberts          2007                  2  2006-07    19
# 5           Aaron Gray          2007                  4  2006-07    22
# 6         Nick Fazekas          2007                  4  2006-07    21
# 7           Nick Young          2007                  3  2006-07    21
# 8    Jermareo Davidson          2007                  4  2006-07    22
# 9        Chris Richard          2007                  4  2006-07    22
# 10        Daequan Cook          2007                  1  2006-07    19
# 11           Greg Oden          2007                  1  2006-07    19
# 12      Rodney Stuckey          2007                  2  2006-07    20
# 13        Jared Dudley          2007                  4  2006-07    21
# 14      Thaddeus Young          2007                  1  2006-07    18
# 15        Kevin Durant          2007                  1  2006-07    18
# 16      Stephane Lasme          2007                  4  2006-07    24
# 17         Gabe Pruitt          2007                  3  2006-07    20
# 18     D.J. Strawberry          2007                  4  2006-07    21
# 19       Julian Wright          2007                  2  2006-07    19
# 20        Aaron Brooks          2007                  4  2006-07    22
# 21         Jason Smith          2007                  3  2006-07    20
# 22    Demetris Nichols          2007                  4  2006-07    22
# 23         Mike Conley          2007                  1  2006-07    19
# 24            Acie Law          2007                  4  2006-07    22
# 25        Corey Brewer          2007                  3  2006-07    20
# 26       Arron Afflalo          2007                  3  2006-07    21
# 27       Morris Almond          2007                  4  2006-07    21
# 28       Spencer Hawes          2007                  1  2006-07    18
# 29     Marcus Williams          2007                  2  2006-07    20
# 30      Ramon Sessions          2007                  3  2006-07    20
# 31       Alando Tucker          2007                  5  2006-07    22
# 32     Dominic McGuire          2007                  3  2006-07    21
# 33         Carl Landry          2007                  3  2006-07    23
# 34       Taurean Green          2007                  3  2006-07    20
# 35      Brandan Wright          2007                  1  2006-07    19
# 36       Sean Williams          2007                  3  2006-07    20
# 37       Derrick Byars          2007                  4  2006-07    22
# 38       JamesOn Curry          2007                  3  2006-07    21
# 39          Glen Davis          2007                  3  2006-07    21
# 40          Al Horford          2007                  3  2006-07    20
# 41     Wilson Chandler          2007                  2  2006-07    19
#
#        College   G      MP   FG   FGA   ...       BLK   TOV   PTS    FG%  \
# 0   GEORGETOWN  37  1232.0  196   382   ...      43.0   NaN   528  0.513
# 1    FLORIDAST  35  1092.0  244   460   ...      40.0   NaN   690  0.530
# 2      FLORIDA  40  1034.0  173   285   ...      72.0   NaN   479  0.607
# 3       GATECH  32  1003.0  158   351   ...       2.0   NaN   460  0.450
# 4         DUKE  33  1164.0  164   327   ...      82.0   NaN   430  0.502
# 5         PITT  36  1016.0  204   361   ...      62.0   NaN   499  0.565
# 6       NEVADA  32   969.0  248   437   ...      48.0   NaN   652  0.568
# 7          USC  37  1227.0  239   455   ...      10.0   NaN   647  0.525
# 8      ALABAMA  30   968.0  149   366   ...      70.0   NaN   419  0.407
# 9      FLORIDA  40   735.0   98   142   ...      12.0   NaN   248  0.690
# 10      OHIOST  39   770.0  141   317   ...      10.0   NaN   382  0.445
# 11      OHIOST  32   925.0  189   307   ...     105.0   NaN   501  0.616
# 12  EWASHINGTN  29   965.0  227   501   ...       9.0   NaN   712  0.453
# 13  BOSTONCOLL  30  1152.0  195   347   ...      10.0   NaN   571  0.562
# 14      GATECH  31   917.0  177   370   ...      12.0   NaN   445  0.478
# 15       TEXAS  35  1255.0  306   647   ...      67.0   NaN   903  0.473
# 16       UMASS  33  1010.0  165   270   ...     168.0   NaN   447  0.611
# 17         USC  26   861.0  104   250   ...       7.0   NaN   324  0.416
# 18    MARYLAND  34  1083.0  184   386   ...      14.0   NaN   505  0.477
# 19      KANSAS  38  1048.0  190   346   ...      49.0   NaN   456  0.549
# 20      OREGON  35  1289.0  213   463   ...       6.0   NaN   621  0.460
# 21  COLORADOST  30   905.0  175   302   ...      47.0   NaN   504  0.579
# 22    SYRACUSE  35  1217.0  225   503   ...      37.0   NaN   663  0.447
# 23      OHIOST  39  1231.0  160   309   ...      10.0   NaN   441  0.518
# 24     TEXASAM  34  1153.0  216   432   ...       1.0   NaN   614  0.500
# 25     FLORIDA  37  1053.0  169   356   ...      15.0   NaN   490  0.475
# 26        UCLA  36  1186.0  210   456   ...       8.0   NaN   608  0.461
# 27        RICE  32  1069.0  263   544   ...      24.0   NaN   844  0.483
# 28  WASHINGTON  31   896.0  193   363   ...      54.0   NaN   461  0.532
# 29     ARIZONA  30   987.0  196   397   ...       NaN   NaN   497  0.494
# 30      NEVADA  34  1028.0  140   310   ...       7.0   NaN   417  0.452
# 31   WISCONSIN  36  1181.0  256   545   ...      10.0   NaN   716  0.470
# 32    FRESNOST  32  1054.0  153   325   ...     114.0   NaN   432  0.471
# 33      PURDUE  34  1035.0  219   367   ...      32.0   NaN   643  0.597
# 34     FLORIDA  40  1328.0  154   347   ...       1.0   NaN   531  0.444
# 35         UNC  37  1013.0  228   353   ...      65.0   NaN   545  0.646
# 36  BOSTONCOLL  15   483.0   63   115   ...      75.0   NaN   182  0.548
# 37       VANDY  34     NaN  206   451   ...       4.0   NaN   577  0.457
# 38     OKSTATE  35     NaN  202   447   ...      11.0   NaN   607  0.452
# 39         LSU  29  1016.0  178   368   ...      28.0   NaN   512  0.484
# 40     FLORIDA  38  1057.0  186   306   ...      70.0   NaN   502  0.608
# 41      DEPAUL  34  1078.0  194   431   ...      47.0   NaN   497  0.450
#
#       3p%    FT%   PG_MP   PG_PTS   PG_TRB   PG_AST
# 0   0.375  0.775    33.3     14.3      6.4      3.2
# 1   0.444  0.790    31.2     19.7      7.2      0.7
# 2   1.000  0.663    25.9     12.0      8.4      2.3
# 3   0.356  0.783    31.3     14.4      3.7      5.8
# 4   0.217  0.664    35.3     13.0      7.9      3.5
# 5     NaN  0.548    28.2     13.9      9.5      1.7
# 6   0.431  0.848    30.3     20.4     11.1      1.8
# 7   0.440  0.786    33.2     17.5      4.6      1.4
# 8   0.250  0.775    32.3     14.0      8.2      1.5
# 9     NaN  0.627    18.4      6.2      3.7      0.4
# 10  0.415  0.697    19.7      9.8      4.3      1.0
# 11    NaN  0.628    28.9     15.7      9.6      0.7
# 12  0.267  0.846    33.3     24.6      4.7      5.5
# 13  0.443  0.743    38.4     19.0      8.3      3.0
# 14  0.419  0.743    29.6     14.4      4.9      2.0
# 15  0.404  0.816    35.9     25.8     11.1      1.3
# 16    NaN  0.622    30.6     13.5      9.5      0.8
# 17  0.350  0.800    33.1     12.5      2.8      4.3
# 18  0.343  0.685    31.9     14.9      4.4      3.5
# 19  0.231  0.613    27.6     12.0      7.8      2.2
# 20  0.404  0.846    36.8     17.7      4.3      4.3
# 21  0.000  0.770    30.2     16.8     10.1      1.9
# 22  0.417  0.850    34.8     18.9      5.4      1.5
# 23  0.304  0.694    31.6     11.3      3.4      6.1
# 24  0.458  0.778    33.9     18.1      3.3      5.0
# 25  0.336  0.723    28.5     13.2      4.7      2.9
# 26  0.375  0.802    32.9     16.9      2.8      1.9
# 27  0.456  0.846    33.4     26.4      6.6      1.2
# 28  0.333  0.755    28.9     14.9      6.4      1.9
# 29  0.288  0.695    32.9     16.6      6.7      2.2
# 30  0.380  0.825    30.2     12.3      4.7      4.7
# 31  0.325  0.659    32.8     19.9      5.4      2.0
# 32  0.299  0.586    32.9     13.5      9.8      3.3
# 33  0.211  0.726    30.4     18.9      7.3      1.2
# 34  0.406  0.849    33.2     13.3      2.4      3.7
# 35    NaN  0.567    27.4     14.7      6.2      1.0
# 36    NaN  0.700    32.2     12.1      6.9      1.2
# 37  0.373  0.711     NaN     17.0      4.9      3.4
# 38  0.411  0.793     NaN     17.3      3.2      3.7
# 39  0.347  0.713    35.0     17.7     10.4      2.3
# 40  0.000  0.644    27.8     13.2      9.5      2.2
# 41  0.333  0.654    31.7     14.6      6.9      1.4
#
# [42 rows x 28 columns]

# %% [markdown]
# # Avg. of 2010-11 to 2014-15

# %%
names = list(draft2007['Name'][1:])
namenyear = draft2007[['Name', ' Years in College']][1:] 
namenyear = namenyear.sort_values('Name')
namenyear = namenyear.reset_index()
namenyear = namenyear.drop('index', 1)

            
#------------------------------------------------------------

n1112 = []
for i in range(len(data1112['Player'])):
    for j in range(len(names)):
        if data1112['Player'][i] == names[j]:
            n1112.append(names[j])       
n1112 = list(set(n1112)) 

f1112 = pd.DataFrame(index=range(len(n1112)),columns=data1112.columns)

for i in range(len(n1112)):

    for word in f1112.columns:

         f1112[word][i] = data1112.loc[data1112['Player'] == n1112[i]][word].values[0] 

#------------------------------------------------------------

n1011 = []
for i in range(len(data1011['Player'])):
    for j in range(len(names)):
        if data1011['Player'][i] == names[j]:
            n1011.append(names[j])       
n1011 = list(set(n1011)) 

f1011 = pd.DataFrame(index=range(len(n1011)),columns=data1011.columns)

for i in range(len(n1011)):

    for word in f1011.columns:

         f1011[word][i] = data1011.loc[data1011['Player'] == n1011[i]][word].values[0] 
            
#------------------------------------------------------------

n0910 = []
for i in range(len(data0910['Player'])):
    for j in range(len(names)):
        if data0910['Player'][i] == names[j]:
            n0910.append(names[j])       
n0910 = list(set(n0910))

f0910 = pd.DataFrame(index=range(len(n0910)),columns=data0910.columns)

for i in range(len(n0910)):

    for word in f0910.columns:

         f0910[word][i] = data0910.loc[data0910['Player'] == n0910[i]][word].values[0]
            
#------------------------------------------------------------

n0809 = []
for i in range(len(data0809['Player'])):
    for j in range(len(names)):
        if data0809['Player'][i] == names[j]:
            n0809.append(names[j])       
n0809 = list(set(n0809))

f0809 = pd.DataFrame(index=range(len(n0809)),columns=data0809.columns)

for i in range(len(n0809)):

    for word in f0809.columns:

         f0809[word][i] = data0809.loc[data0809['Player'] == n0809[i]][word].values[0]
            
#------------------------------------------------------------

n0708 = []
for i in range(len(data0708['Player'])):
    for j in range(len(names)):
        if data0708['Player'][i] == names[j]:
            n0708.append(names[j])       
n0708 = list(set(n0708))

f0708 = pd.DataFrame(index=range(len(n0708)),columns=data0708.columns)

for i in range(len(n0708)):

    for word in f0708.columns:

         f0708[word][i] = data0708.loc[data0708['Player'] == n0708[i]][word].values[0]
                       

final = f0708.append([f0910, f0809, f1112, f1011])
final = final.reset_index()
final.drop(['index'], axis=1, inplace=True)

final['Age']= final['Age'].astype('float64')
final['G']= final['G'].astype('float64')
final['GS']= final['GS'].astype('float64')
final['MP']= final['MP'].astype('float64')
final['FG']= final['FG'].astype('float64')
final['FGA']= final['FGA'].astype('float64')
final['FG%']= final['FG%'].astype('float64')
final['3P']= final['3P'].astype('float64')
final['3PA']= final['3PA'].astype('float64')
final['3P%']= final['3P%'].astype('float64')
final['2P']= final['2P'].astype('float64')
final['2PA']= final['2PA'].astype('float64')
final['2P%']= final['2P%'].astype('float64')
final['eFG%']= final['eFG%'].astype('float64')
final['FT']= final['FT'].astype('float64')
final['FTA']= final['FTA'].astype('float64')
final['FT%']= final['FT%'].astype('float64')
final['ORB']= final['ORB'].astype('float64')
final['DRB']= final['DRB'].astype('float64')
final['TRB']= final['TRB'].astype('float64')
final['AST']= final['AST'].astype('float64')
final['STL']= final['STL'].astype('float64')
final['BLK']= final['BLK'].astype('float64')
final['TOV']= final['TOV'].astype('float64')
final['PF']= final['PF'].astype('float64')
final['PS/G']= final['PS/G'].astype('float64')

finaldata = final.groupby('Player', as_index=False).mean()
finaldata.insert(1, "Years in College", namenyear[' Years in College']) 
finaldata['Years in College'] = 0

finaldata = finaldata[['Player', 'Years in College', 'Age', 'G', 'GS', 'MP', 'FG', 'FGA',
       'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA',
       'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PS/G']]

# %%
x = []
for i in range(len(finaldata['Player'])):
    for j in range(len(n1112)):
        if finaldata['Player'][i] == n1112[j]:
            x.append(n1112[j])       
f = list(set(x))

test = finaldata

test = test[test['Player'].isin(f)].reset_index().drop('index', 1)

test.to_csv('Desktop/finaldata/2007draft.csv', sep='\t', encoding='utf-8')
test
# Out:
#              Player  Years in College   Age     G    GS     MP    FG    FGA  \
# 0        Aaron Gray                 0  26.5  45.0  23.0  14.80  1.55   2.85
# 1        Al Horford                 0  24.5  44.0  44.0  33.35  5.95  10.70
# 2     Arron Afflalo                 0  25.5  65.5  65.5  33.65  4.90  10.20
# 3    Brandan Wright                 0  23.5  43.0   1.0  13.15  2.25   4.00
# 4       Carl Landry                 0  27.5  58.5  17.0  25.40  4.45   8.90
# 5      Corey Brewer                 0  24.5  64.0  20.5  21.85  3.10   7.45
# 6      Daequan Cook                 0  23.5  50.0  11.0  15.65  1.85   4.70
# 7     Derrick Byars                 0  27.0   2.0   0.0  18.50  1.50   5.50
# 8   Dominic McGuire                 0  25.5  58.0   7.0  16.10  1.45   3.40
# 9        Glen Davis                 0  25.5  69.5  13.0  26.45  4.15   9.55
# 10     Jared Dudley                 0  25.5  73.5  37.5  28.60  4.25   8.80
# 11      Jason Smith                 0  24.5  58.5  17.5  19.00  3.15   6.35
# 12      Joakim Noah                 0  25.5  56.0  56.0  31.60  4.15   8.05
# 13   Josh McRoberts                 0  23.5  61.0  28.5  18.30  2.00   3.90
# 14     Kevin Durant                 0  22.5  72.0  72.0  38.75  9.40  19.70
# 15      Mike Conley                 0  23.5  71.5  71.0  35.30  5.00  11.40
# 16    Morris Almond                 0  26.0   4.0   0.0  16.80  1.50   4.30
# 17       Nick Young                 0  25.5  63.0  37.5  29.85  5.75  13.60
# 18   Ramon Sessions                 0  24.5  72.5  30.5  26.50  4.15   9.20
# 19   Rodney Stuckey                 0  24.5  62.5  51.0  30.55  4.95  11.35
# 20    Sean Williams                 0  25.0  11.0   0.0   9.70  1.30   2.00
# 21    Spencer Hawes                 0  22.5  59.0  55.0  23.05  3.75   7.80
# 22   Thaddeus Young                 0  22.5  72.5   1.0  26.95  5.55  10.60
# 23  Wilson Chandler                 0  23.5  40.0  27.5  30.10  4.95  11.55
#
#        FG%    3P  ...       FT%   ORB   DRB    TRB   AST   STL   BLK   TOV  \
# 0   0.5410  0.00  ...    0.5160  1.55  3.35   4.95  0.50  0.35  0.30  0.90
# 1   0.5550  0.00  ...    0.7655  2.40  5.80   8.15  2.85  0.85  1.15  1.50
# 2   0.4845  1.45  ...    0.8225  0.65  2.75   3.40  2.40  0.55  0.30  1.20
# 3   0.5655  0.00  ...    0.6555  1.05  1.95   3.00  0.30  0.35  0.90  0.40
# 4   0.5025  0.00  ...    0.7695  2.05  2.85   4.90  0.85  0.40  0.35  1.50
# 5   0.4145  0.50  ...    0.7000  0.75  1.75   2.50  1.40  1.30  0.25  1.10
# 6   0.4020  1.45  ...    0.7180  0.20  1.70   1.90  0.40  0.35  0.10  0.35
# 7   0.2730  0.00  ...    1.0000  3.00  2.50   5.50  0.50  1.00  0.00  0.00
# 8   0.4220  0.00  ...    0.7525  1.15  2.65   3.80  1.25  0.45  0.60  0.70
# 9   0.4345  0.00  ...    0.7095  1.55  3.95   5.40  1.00  0.85  0.35  1.15
# 10  0.4810  1.25  ...    0.7345  1.45  2.85   4.25  1.50  0.95  0.25  1.00
# 11  0.4815  0.00  ...    0.7725  1.50  2.55   4.00  0.70  0.40  0.70  0.85
# 12  0.5165  0.00  ...    0.7435  3.80  6.30  10.10  2.35  0.80  1.45  1.65
# 13  0.5110  0.20  ...    0.6890  1.35  3.00   4.35  1.55  0.50  0.60  0.95
# 14  0.4790  1.95  ...    0.8700  0.65  6.75   7.40  3.10  1.20  1.10  3.30
# 15  0.4385  1.00  ...    0.7970  0.40  2.45   2.75  6.50  2.00  0.20  2.10
# 16  0.3530  0.30  ...    0.3330  0.30  1.80   2.00  0.50  1.80  0.00  0.30
# 17  0.4220  1.65  ...    0.8340  0.45  1.95   2.40  1.05  0.70  0.30  1.35
# 18  0.4470  0.35  ...    0.8025  0.55  2.70   3.20  5.35  0.70  0.05  2.20
# 19  0.4340  0.50  ...    0.8500  0.85  2.00   2.85  4.50  0.95  0.15  2.05
# 20  0.6360  0.00  ...    0.9230  1.20  1.10   2.30  0.50  0.40  0.70  0.90
# 21  0.4770  0.10  ...    0.6305  1.85  4.65   6.50  2.05  0.40  1.10  1.35
# 22  0.5240  0.05  ...    0.7390  2.05  3.20   5.25  1.10  1.05  0.50  1.05
# 23  0.4210  1.00  ...    0.8200  0.90  4.50   5.40  1.90  0.75  1.05  1.85
#
#       PF   PS/G
# 0   2.45   3.50
# 1   2.20  13.85
# 2   2.20  13.90
# 3   1.05   5.35
# 4   2.40  12.20
# 5   2.10   8.45
# 6   1.20   5.55
# 7   1.00   5.00
# 8   1.70   3.40
# 9   2.35  10.50
# 10  1.65  11.65
# 11  2.25   7.10
# 12  2.90  10.95
# 13  1.90   5.10
# 14  2.00  27.85
# 15  2.15  13.20
# 16  1.50   3.50
# 17  2.30  15.80
# 18  1.35  12.30
# 19  2.40  15.15
# 20  1.60   3.60
# 21  2.60   8.40
# 22  2.05  12.75
# 23  2.55  12.35
#
# [24 rows x 28 columns]
