# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.plotly as py
import warnings
import xgboost as xgb
warnings.filterwarnings('ignore')

# %% [markdown]
# # 2009

# %%
data1314 = pd.read_csv('Downloads/results/input_files/NBA Player Stats - Regular Stats 2013-2014.csv')
data1314.drop(['Tm', 'Rk'], axis=1, inplace=True)
data1213 = pd.read_csv('Downloads/results/input_files/NBA Player Stats - Regular Stats 2012-2013.csv')
data1213.drop(['Tm', 'Rk'], axis=1, inplace=True)
data1112 = pd.read_csv('Downloads/results/input_files/NBA Player Stats - Regular Stats 2011-2012.csv')
data1112.drop(['Tm', 'Rk'], axis=1, inplace=True)
data1011 = pd.read_csv('Downloads/results/input_files/NBA Player Stats - Regular Stats 2010-2011.csv')
data1011.drop(['Tm', 'Rk'], axis=1, inplace=True)
data0910 = pd.read_csv('Downloads/results/input_files/NBA Player Stats - Regular Stats 2009-2010.csv')
data0910.drop(['Tm', 'Rk'], axis=1, inplace=True)
data0910.head()
# Out:
#                         Player Pos   Age     G    GS    MP   FG   FGA    FG%  \
# 0      Arron Afflalo\afflaar01  SG  24.0  82.0  75.0  27.1  3.3   7.1  0.465
# 1      Alexis Ajinca\ajincal01   C  21.0   6.0   0.0   5.0  0.8   1.7  0.500
# 2  LaMarcus Aldridge\aldrila01  PF  24.0  78.0  78.0  37.5  7.4  15.0  0.495
# 3      Joe Alexander\alexajo01  SF  23.0   8.0   0.0   3.6  0.1   0.8  0.167
# 4        Malik Allen\allenma01  PF  31.0  51.0   3.0   8.9  0.9   2.3  0.397
#
#     3P  ...    FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF  PS/G
# 0  1.3  ...  0.735  0.7  2.4  3.1  1.7  0.6  0.4  0.9  2.7   8.8
# 1  0.0  ...  0.000  0.2  0.5  0.7  0.0  0.2  0.2  0.3  0.8   1.7
# 2  0.1  ...  0.757  2.5  5.6  8.0  2.1  0.9  0.6  1.3  3.0  17.9
# 3  0.0  ...  0.667  0.3  0.4  0.6  0.3  0.1  0.1  0.0  1.1   0.5
# 4  0.0  ...  0.923  0.7  0.9  1.6  0.3  0.2  0.1  0.4  1.3   2.1
#
# [5 rows x 28 columns]

# %% [markdown]
# # College data

# %%
draft2009 = pd.read_csv('Downloads/results/input_files/2009_class_urls.csv')
draft2009.columns
college = draft2009[['Name', ' Years in College']]
draft2009
# Out:
#                  Name   Draft Class   Years in College   Season   Age  \
# 0     Wayne Ellington          2009                  3  2008-09    21
# 1    Dante Cunningham          2009                  4  2008-09    21
# 2         Jodie Meeks          2009                  3  2008-09    21
# 3       James Johnson          2009                  2  2008-09    21
# 4     Darren Collison          2009                  4  2008-09    21
# 5       Byron Mullens          2009                  1  2008-09    19
# 6       Patrick Mills          2009                  2  2008-09    20
# 7     Hasheem Thabeet          2009                  3  2008-09    21
# 8        James Harden          2009                  2  2008-09    19
# 9       Lester Hudson          2009                  2  2008-09    24
# 10       DeJuan Blair          2009                  2  2008-09    19
# 11        Austin Daye          2009                  2  2008-09    20
# 12          Ty Lawson          2009                  3  2008-09    21
# 13  Terrence Williams          2009                  4  2008-09    21
# 14    DeMarre Carroll          2009                  4  2008-09    22
# 15     Taylor Griffin          2009                  4  2008-09    22
# 16    Chinemelu Elonu          2009                  3  2008-09    21
# 17   Gerald Henderson          2009                  3  2008-09    21
# 18     Chase Budinger          2009                  3  2008-09    20
# 19      Blake Griffin          2009                  2  2008-09    19
# 20       Tyreke Evans          2009                  1  2008-09    19
# 21   Patrick Beverley          2009                  2  2007-08    19
# 22      Stephen Curry          2009                  3  2008-09    20
# 23          Sam Young          2009                  4  2008-09    23
# 24        Eric Maynor          2009                  4  2008-09    21
# 25       Jrue Holiday          2009                  1  2008-09    18
# 26    Marcus Thornton          2009                  2  2008-09    21
# 27      Toney Douglas          2009                  4  2008-09    22
# 28         Taj Gibson          2009                  3  2008-09    23
# 29        Jordan Hill          2009                  3  2008-09    21
# 30        Jeff Teague          2009                  2  2008-09    20
# 31         Earl Clark          2009                  3  2008-09    21
# 32        Danny Green          2009                  4  2008-09    21
# 33     DaJuan Summers          2009                  3  2008-09    21
# 34         A.J. Price          2009                  3  2008-09    22
# 35        Jonny Flynn          2009                  2  2008-09    19
# 36       Jon Brockman          2009                  4  2008-09    21
# 37    Jermaine Taylor          2009                  4  2008-09    22
# 38      Nick Calathes          2009                  2  2008-09    19
# 39   Jeff Pendergraph          2009                  4  2008-09    21
# 40      DeMar DeRozan          2009                  1  2008-09    19
# 41   Tyler Hansbrough          2009                  4  2008-09    23
# 42      Derrick Brown          2009                  3  2008-09    21
#
#        College   G   MP   FG   FGA  ...   BLK   TOV   PTS    FG%    3p%  \
# 0          UNC  38  NaN  215   445  ...     6    62   602  0.483  0.417
# 1    VILLANOVA  38  NaN  244   465  ...    47    82   612  0.525  0.000
# 2     KENTUCKY  36  NaN  263   568  ...     5    96   854  0.463  0.406
# 3         WAKE  31  NaN  187   345  ...    48    74   465  0.542  0.319
# 4         UCLA  35  NaN  175   344  ...     5    87   504  0.509  0.394
# 5       OHIOST  33  NaN  120   188  ...    37    51   292  0.638  0.000
# 6    STMARYSCA  26  NaN  163   405  ...     6    75   478  0.402  0.338
# 7        UCONN  36  NaN  178   278  ...   152    68   489  0.640    NaN
# 8    ARIZONAST  35  NaN  221   452  ...    11   118   704  0.489  0.356
# 9     TNMARTIN  32  NaN  313   697  ...    18   106   880  0.449  0.355
# 10        PITT  35  NaN  226   381  ...    34    44   550  0.593    NaN
# 11     GONZAGA  34  NaN  159   333  ...    70    73   431  0.477  0.429
# 12         UNC  35  NaN  182   342  ...     5    66   581  0.532  0.472
# 13  LOUISVILLE  37  NaN  169   392  ...    29    86   463  0.431  0.385
# 14    MISSOURI  38  NaN  246   441  ...    25    56   629  0.558  0.364
# 15    OKLAHOMA  36  NaN  125   233  ...    36    62   346  0.536  0.357
# 16     TEXASAM  34  NaN  129   194  ...    53    62   334  0.665    NaN
# 17        DUKE  37  NaN  213   473  ...    28    80   610  0.450  0.336
# 18     ARIZONA  35  NaN  219   456  ...    16    85   630  0.480  0.399
# 19    OKLAHOMA  35  NaN  300   459  ...    41   116   794  0.654  0.375
# 20     MEMPHIS  37  NaN  230   505  ...    29   133   632  0.455  0.274
# 21    ARKANSAS  35  NaN  136   330  ...    16    69   422  0.412  0.378
# 22    DAVIDSON  34  NaN  312   687  ...     8   126   974  0.454  0.387
# 23        PITT  36  NaN  261   520  ...    30    88   690  0.502  0.372
# 24         VCU  34  NaN  248   536  ...     6   101   760  0.463  0.361
# 25        UCLA  35  NaN  112   249  ...    18    75   296  0.450  0.307
# 26         LSU  35  NaN  256   542  ...    13    64   739  0.472  0.388
# 27   FLORIDAST  35  NaN  239   536  ...    15    87   751  0.446  0.385
# 28         USC  35  NaN  190   316  ...   100    72   500  0.601    NaN
# 29     ARIZONA  34  NaN  252   469  ...    58    97   621  0.537    NaN
# 30        WAKE  31  NaN  180   371  ...    20   104   584  0.485  0.441
# 31  LOUISVILLE  37  NaN  202   442  ...    51   119   525  0.457  0.326
# 32         UNC  38  NaN  184   391  ...    51    63   497  0.471  0.418
# 33  GEORGETOWN  31  NaN  137   289  ...    21    81   423  0.474  0.385
# 34       UCONN  35  NaN  170   417  ...     0    94   515  0.408  0.402
# 35    SYRACUSE  38  NaN  219   476  ...     6   129   663  0.460  0.317
# 36  WASHINGTON  34  NaN  190   361  ...     3    65   506  0.526  0.000
# 37    CFLORIDA  31  NaN  291   606  ...    24    87   812  0.480  0.376
# 38     FLORIDA  36  NaN  205   425  ...     6   119   618  0.482  0.390
# 39   ARIZONAST  35  NaN  198   300  ...    30    43   509  0.660  0.000
# 40         USC  35  NaN  192   367  ...    13    73   485  0.523  0.167
# 41         UNC  34  NaN  223   434  ...    12    63   704  0.514  0.391
# 42      XAVIER  35  NaN  170   337  ...    30    61   479  0.504  0.433
#
#       FT%   PG_MP   PG_PTS   PG_TRB   PG_AST
# 0   0.777     NaN     15.8      4.9      2.7
# 1   0.697     NaN     16.1      7.5      1.2
# 2   0.902     NaN     23.7      3.4      1.8
# 3   0.697     NaN     15.0      8.5      2.0
# 4   0.897     NaN     14.4      2.4      4.7
# 5   0.559     NaN      8.8      4.7      0.3
# 6   0.859     NaN     18.4      2.4      3.9
# 7   0.627     NaN     13.6     10.8      0.5
# 8   0.756     NaN     20.1      5.6      4.2
# 9   0.881     NaN     27.5      7.9      4.2
# 10  0.605     NaN     15.7     12.3      1.2
# 11  0.706     NaN     12.7      6.8      1.1
# 12  0.798     NaN     16.6      3.0      6.6
# 13  0.581     NaN     12.5      8.6      5.0
# 14  0.634     NaN     16.6      7.2      2.2
# 15  0.700     NaN      9.6      5.8      1.3
# 16  0.628     NaN      9.8      7.3      0.3
# 17  0.761     NaN     16.5      4.9      2.5
# 18  0.801     NaN     18.0      6.2      3.4
# 19  0.590     NaN     22.7     14.4      2.3
# 20  0.711     NaN     17.1      5.4      3.9
# 21  0.644     NaN     12.1      6.6      2.4
# 22  0.876     NaN     28.6      4.4      5.6
# 23  0.740     NaN     19.2      6.3      1.1
# 24  0.815     NaN     22.4      3.6      6.2
# 25  0.726     NaN      8.5      3.8      3.7
# 26  0.745     NaN     21.1      5.5      2.1
# 27  0.810     NaN     21.5      3.9      2.9
# 28  0.659     NaN     14.3      9.0      1.3
# 29  0.654     NaN     18.3     11.0      1.5
# 30  0.817     NaN     18.8      3.3      3.5
# 31  0.647     NaN     14.2      8.7      3.2
# 32  0.852     NaN     13.1      4.7      2.7
# 33  0.713     NaN     13.6      4.1      1.3
# 34  0.721     NaN     14.7      3.5      4.7
# 35  0.786     NaN     17.4      2.7      6.7
# 36  0.640     NaN     14.9     11.5      1.1
# 37  0.812     NaN     26.2      5.2      1.9
# 38  0.707     NaN     17.2      5.3      6.4
# 39  0.779     NaN     14.5      8.2      0.9
# 40  0.646     NaN     13.9      5.7      1.5
# 41  0.841     NaN     20.7      8.1      1.0
# 42  0.741     NaN     13.7      6.1      1.9
#
# [43 rows x 28 columns]

# %% [markdown]
# # Avg. of 2009-10 to 2013-14

# %%
names = list(draft2009['Name'][1:])
namenyear = draft2009[['Name', ' Years in College']][1:] 
namenyear = namenyear.sort_values('Name')
namenyear = namenyear.reset_index()
namenyear = namenyear.drop('index', 1)


#------------------------------------------------------------

n1314 = []
for i in range(len(data1314['Player'])):
    for j in range(len(names)):
        if data1314['Player'][i] == names[j]:
            n1314.append(names[j])       
n1314 = list(set(n1314)) 

f1314 = pd.DataFrame(index=range(len(n1314)),columns=data1314.columns)

for i in range(len(n1314)):

    for word in f1314.columns:

         f1314[word][i] = data1314.loc[data1314['Player'] == n1314[i]][word].values[0]            
        
#------------------------------------------------------------

n1213 = []
for i in range(len(data1213['Player'])):
    for j in range(len(names)):
        if data1213['Player'][i] == names[j]:
            n1213.append(names[j])       
n1213 = list(set(n1213)) 

f1213 = pd.DataFrame(index=range(len(n1213)),columns=data1213.columns)

for i in range(len(n1213)):

    for word in f1213.columns:

         f1213[word][i] = data1213.loc[data1213['Player'] == n1213[i]][word].values[0] 
            
#------------------------------------------------------------

n1112 = []
for i in range(len(data1112['Player'])):
    for j in range(len(names)):
        if data1112['Player'][i] == names[j]:
            n1112.append(names[j])       
n1112 = list(set(n1112)) 

f1112 = pd.DataFrame(index=range(len(n1112)),columns=data1112.columns)

for i in range(len(n1112)):

    for word in f1112.columns:

         f1112[word][i] = data1112.loc[data1112['Player'] == n1112[i]][word].values[0] 

#------------------------------------------------------------

n1011 = []
for i in range(len(data1011['Player'])):
    for j in range(len(names)):
        if data1011['Player'][i] == names[j]:
            n1011.append(names[j])       
n1011 = list(set(n1011)) 

f1011 = pd.DataFrame(index=range(len(n1011)),columns=data1011.columns)

for i in range(len(n1011)):

    for word in f1011.columns:

         f1011[word][i] = data1011.loc[data1011['Player'] == n1011[i]][word].values[0] 
            
#------------------------------------------------------------

n0910 = []
for i in range(len(data0910['Player'])):
    for j in range(len(names)):
        if data0910['Player'][i] == names[j]:
            n0910.append(names[j])       
n0910 = list(set(n0910))

f0910 = pd.DataFrame(index=range(len(n0910)),columns=data0910.columns)

for i in range(len(n0910)):

    for word in f0910.columns:

         f0910[word][i] = data0910.loc[data0910['Player'] == n0910[i]][word].values[0]
                       

final = f0910.append([f1314, f1213, f1112, f1011])
final = final.reset_index()
final.drop(['index'], axis=1, inplace=True)

final['Age']= final['Age'].astype('float64')
final['G']= final['G'].astype('float64')
final['GS']= final['GS'].astype('float64')
final['MP']= final['MP'].astype('float64')
final['FG']= final['FG'].astype('float64')
final['FGA']= final['FGA'].astype('float64')
final['FG%']= final['FG%'].astype('float64')
final['3P']= final['3P'].astype('float64')
final['3PA']= final['3PA'].astype('float64')
final['3P%']= final['3P%'].astype('float64')
final['2P']= final['2P'].astype('float64')
final['2PA']= final['2PA'].astype('float64')
final['2P%']= final['2P%'].astype('float64')
final['eFG%']= final['eFG%'].astype('float64')
final['FT']= final['FT'].astype('float64')
final['FTA']= final['FTA'].astype('float64')
final['FT%']= final['FT%'].astype('float64')
final['ORB']= final['ORB'].astype('float64')
final['DRB']= final['DRB'].astype('float64')
final['TRB']= final['TRB'].astype('float64')
final['AST']= final['AST'].astype('float64')
final['STL']= final['STL'].astype('float64')
final['BLK']= final['BLK'].astype('float64')
final['TOV']= final['TOV'].astype('float64')
final['PF']= final['PF'].astype('float64')
final['PS/G']= final['PS/G'].astype('float64')

finaldata = final.groupby('Player', as_index=False).mean()
finaldata.insert(1, "Years in College", namenyear[' Years in College']) 
finaldata['Years in College'] = 0

finaldata = finaldata[['Player', 'Years in College', 'Age', 'G', 'GS', 'MP', 'FG', 'FGA',
       'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA',
       'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PS/G']]

# %%
x = []
for i in range(len(finaldata['Player'])):
    for j in range(len(n1314)):
        if finaldata['Player'][i] == n1314[j]:
            x.append(n1314[j])        
f = list(set(x))

test = finaldata

test = test[test['Player'].isin(f)].reset_index().drop('index', 1)

combined = college
combined = combined.sort_values('Name').reset_index().drop('index', 1)
combined['Player'] = test['Player']
combined['check'] = combined['Name'].isin(combined['Player'])
combined = combined[combined.check == True]
combined = combined[['Name', ' Years in College']]
years = list(combined[' Years in College'])
test['Years in College'] = years

test
#test.to_csv('Desktop/finaldata/2009draft.csv', sep='\t', encoding='utf-8')
# Out:
#               Player  Years in College   Age      G     GS      MP     FG  \
# 0         A.J. Price                 3  25.5  44.75   5.75  13.675  1.775
# 1        Austin Daye                 2  23.5  47.50   5.25  13.450  1.800
# 2      Blake Griffin                 2  22.5  77.00  77.00  35.625  8.300
# 3      Byron Mullens                 1  22.5  44.00  16.50  16.275  2.575
# 4     Chase Budinger                 3  23.5  50.00  10.00  21.275  3.250
# 5        Danny Green                 4  24.5  55.50  44.25  21.600  3.050
# 6   Dante Cunningham                 4  24.5  75.75   9.75  20.975  2.975
# 7    Darren Collison                 4  24.5  75.00  54.25  29.100  4.275
# 8       DeJuan Blair                 2  22.5  71.00  39.00  18.075  3.200
# 9      DeMar DeRozan                 1  22.5  76.50  76.50  36.175  6.725
# 10   DeMarre Carroll                 4  25.5  43.75  23.50  16.900  2.125
# 11        Earl Clark                 3  24.5  50.00  13.50  15.175  1.850
# 12       Eric Maynor                 4  24.5  46.50   0.00  13.825  1.475
# 13  Gerald Henderson                 3  24.5  67.00  55.00  30.275  5.150
# 14   Hasheem Thabeet                 3  24.5  39.00   1.75   8.725  0.650
# 15      James Harden                 2  22.5  73.75  39.50  33.600  5.900
# 16     James Johnson                 2  24.5  51.50  20.00  20.375  2.900
# 17       Jeff Teague                 2  23.5  73.75  57.50  28.000  4.500
# 18       Jodie Meeks                 3  24.5  73.75  48.50  26.825  3.550
# 19       Jordan Hill                 3  24.5  53.00  13.00  16.575  2.800
# 20      Jrue Holiday                 1  21.5  64.75  64.75  35.075  6.000
# 21   Marcus Thornton                 2  24.5  67.00  27.25  26.850  4.950
# 22     Nick Calathes                 2  24.0  71.00   7.00  16.500  2.000
# 23  Patrick Beverley                 2  24.5  48.50  27.50  24.350  2.750
# 24     Stephen Curry                 3  23.5  64.00  63.25  34.125  7.200
# 25        Taj Gibson                 3  26.5  72.50   8.00  23.325  3.650
# 26     Toney Douglas                 4  25.5  60.25   8.75  18.250  2.600
# 27         Ty Lawson                 3  24.5  69.00  56.00  32.825  5.525
# 28  Tyler Hansbrough                 4  26.5  70.25  10.25  18.975  2.675
# 29      Tyreke Evans                 1  22.5  64.25  49.25  32.625  6.050
#
#        FGA      FG%     3P  ...       FT%    ORB    DRB     TRB    AST    STL  \
# 0    4.800  0.37450  0.700  ...  0.564250  0.250  1.025   1.300  2.075  0.425
# 1    4.725  0.37950  0.625  ...  0.734500  0.425  1.925   2.350  0.775  0.375
# 2   15.675  0.53025  0.100  ...  0.634500  2.825  7.375  10.200  3.650  1.000
# 3    6.400  0.39325  0.525  ...  0.616750  0.950  2.875   3.800  0.675  0.350
# 4    7.750  0.41875  1.175  ...  0.802250  0.650  2.600   3.225  1.200  0.525
# 5    6.825  0.45200  1.625  ...  0.810667  0.525  2.425   2.975  1.225  0.850
# 6    6.300  0.47750  0.000  ...  0.648750  1.450  2.675   4.150  0.750  0.825
# 7    9.325  0.45875  0.650  ...  0.859500  0.500  2.250   2.750  4.675  1.075
# 8    6.125  0.52325  0.000  ...  0.633750  2.000  3.250   5.250  0.950  0.875
# 9   15.300  0.44075  0.425  ...  0.819500  0.675  3.150   3.825  2.575  0.950
# 10   4.775  0.41825  0.475  ...  0.853250  1.050  1.775   2.800  0.950  0.750
# 11   4.550  0.40225  0.350  ...  0.660500  0.875  2.450   3.325  0.500  0.350
# 12   4.025  0.36375  0.525  ...  0.750000  0.250  0.975   1.225  2.450  0.400
# 13  11.550  0.44825  0.325  ...  0.782500  0.775  2.925   3.700  2.250  0.825
# 14   1.150  0.52950  0.000  ...  0.499250  0.675  1.400   2.100  0.075  0.250
# 15  13.000  0.45525  1.975  ...  0.851500  0.650  3.550   4.200  4.425  1.375
# 16   6.425  0.44575  0.225  ...  0.701750  1.075  2.525   3.575  1.875  0.900
# 17   9.975  0.45075  0.775  ...  0.819500  0.300  1.875   2.200  5.200  1.200
# 18   8.300  0.42100  1.775  ...  0.888250  0.375  2.000   2.350  1.150  0.900
# 19   5.400  0.50850  0.000  ...  0.671250  2.225  3.325   5.550  0.500  0.325
# 20  13.725  0.43900  1.025  ...  0.792000  0.900  3.025   3.925  6.725  1.575
# 21  11.625  0.42375  1.700  ...  0.834500  0.975  2.125   3.125  1.525  0.975
# 22   4.400  0.45700  0.300  ...  0.611000  0.300  1.600   1.900  2.900  0.900
# 23   6.600  0.41600  1.250  ...  0.821500  1.200  1.900   3.100  2.800  1.150
# 24  15.275  0.47300  2.725  ...  0.882000  0.675  3.250   3.900  6.625  1.550
# 25   7.600  0.48125  0.000  ...  0.682000  2.100  3.650   5.775  0.850  0.450
# 26   6.800  0.38175  1.075  ...  0.820000  0.525  1.650   2.125  2.100  0.825
# 27  11.875  0.47075  1.125  ...  0.785500  0.700  2.400   3.125  6.750  1.350
# 28   6.050  0.44400  0.000  ...  0.748250  1.925  2.775   4.675  0.450  0.525
# 29  13.750  0.44400  0.525  ...  0.774000  0.950  3.725   4.625  4.650  1.350
#
#       BLK    TOV     PF    PS/G
# 0   0.025  0.800  0.850   4.925
# 1   0.400  0.625  1.525   4.925
# 2   0.600  2.525  3.150  21.325
# 3   0.450  0.925  1.600   6.500
# 4   0.150  0.850  1.325   8.875
# 5   0.600  0.975  1.425   8.450
# 6   0.575  0.600  1.875   6.600
# 7   0.175  2.050  1.675  11.750
# 8   0.300  1.150  2.375   7.400
# 9   0.350  1.950  2.450  18.675
# 10  0.200  0.525  1.575   5.600
# 11  0.575  0.750  1.400   4.675
# 12  0.050  1.050  1.000   3.875
# 13  0.450  1.450  2.075  13.550
# 14  0.525  0.500  1.700   1.625
# 15  0.350  2.725  2.400  20.075
# 16  1.100  1.475  2.300   7.175
# 17  0.400  2.175  1.925  12.225
# 18  0.075  0.825  1.325  10.625
# 19  0.750  0.900  2.075   6.750
# 20  0.375  2.900  2.375  14.875
# 21  0.150  1.175  1.675  13.500
# 22  0.100  1.400  1.600   4.900
# 23  0.450  1.150  2.550   7.900
# 24  0.250  3.125  2.625  20.050
# 25  1.350  1.225  2.425   8.950
# 26  0.025  1.100  1.800   7.075
# 27  0.125  2.450  1.700  15.600
# 28  0.200  0.950  2.175   8.050
# 29  0.425  2.575  2.225  16.000
#
# [30 rows x 28 columns]
