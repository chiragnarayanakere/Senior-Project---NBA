# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.plotly as py
import warnings
import xgboost as xgb
warnings.filterwarnings('ignore')

# %% [markdown]
# # 2012 draft class

# %%
data1617 = pd.read_csv('Downloads/NBA Player Stats - Regular Stats 2016-2017.csv')
data1617.drop(['Tm', 'Rk'], axis=1, inplace=True)
data1516 = pd.read_csv('Downloads/NBA Player Stats - Regular Stats 2015-2016.csv')
data1516.drop(['Tm', 'Rk'], axis=1, inplace=True)
data1415 = pd.read_csv('Downloads/NBA Player Stats - Regular Stats 2014-2015.csv')
data1415.drop(['Tm', 'Rk'], axis=1, inplace=True)
data1314 = pd.read_csv('Downloads/NBA Player Stats - Regular Stats 2013-2014.csv')
data1314.drop(['Tm', 'Rk'], axis=1, inplace=True)
data1213 = pd.read_csv('Downloads/NBA Player Stats - Regular Stats 2012-2013.csv')
data1213.drop(['Tm', 'Rk'], axis=1, inplace=True)
data1617.head()
# Out:
#          Player         ID  Age   G  GS    MP   FG  FGA    FG%   3P  ...  \
# 0  Alex Abrines  abrinal01   23  68   6  15.5  2.0  5.0  0.393  1.4  ...
# 1    Quincy Acy    acyqu01   26  38   1  14.7  1.8  4.5  0.412  1.0  ...
# 2    Quincy Acy    acyqu01   26   6   0   8.0  0.8  2.8  0.294  0.2  ...
# 3    Quincy Acy    acyqu01   26  32   1  15.9  2.0  4.8  0.425  1.1  ...
# 4  Steven Adams  adamsst01   23  80  80  29.9  4.7  8.2  0.571  0.0  ...
#
#      FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF  PS/G
# 0  0.898  0.3  1.0  1.3  0.6  0.5  0.1  0.5  1.7   6.0
# 1  0.750  0.5  2.5  3.0  0.5  0.4  0.4  0.6  1.8   5.8
# 2  0.667  0.3  1.0  1.3  0.0  0.0  0.0  0.3  1.5   2.2
# 3  0.754  0.6  2.8  3.3  0.6  0.4  0.5  0.6  1.8   6.5
# 4  0.611  3.5  4.2  7.7  1.1  1.1  1.0  1.8  2.4  11.3
#
# [5 rows x 28 columns]

# %% [markdown]
# # College data

# %%
draft2012 = pd.read_csv('Downloads/csvfiles/2012_class_urls.csv')
draft2012.columns
draft2012
# Out:
#                       Name   Draft Class   Years in College   Season   Age  \
# 0               Mike Scott          2012                  5  2011-12    23
# 1      Darius Johnson-Odom          2012                  3  2011-12    22
# 2              Kris Joseph          2012                  4  2011-12    23
# 3           Marquis Teague          2012                  1  2011-12    18
# 4             Kyle O'Quinn          2012                  4  2011-12    21
# 5          Justin Hamilton          2012                  3  2011-12    21
# 6              Tony Wroten          2012                  1  2011-12    18
# 7            Robbie Hummel          2012                  4  2011-12    22
# 8             Bradley Beal          2012                  1  2011-12    18
# 9           Damian Lillard          2012                  4  2011-12    21
# 10         Thomas Robinson          2012                  3  2011-12    20
# 11            Tyler Zeller          2012                  4  2011-12    22
# 12          Draymond Green          2012                  4  2011-12    21
# 13             John Henson          2012                  3  2011-12    21
# 14           Darius Miller          2012                  4  2011-12    21
# 15        Jared Cunningham          2012                  3  2011-12    20
# 16  Michael Kidd-Gilchrist          2012                  1  2011-12    18
# 17         Khris Middleton          2012                  3  2011-12    20
# 18          Tyshawn Taylor          2012                  4  2011-12    21
# 19              Doron Lamb          2012                  2  2011-12    20
# 20            Festus Ezeli          2012                  4  2011-12    22
# 21        Andrew Nicholson          2012                  4  2011-12    22
# 22           Quincy Miller          2012                  1  2011-12    19
# 23            John Jenkins          2012                  3  2011-12    20
# 24         Harrison Barnes          2012                  2  2011-12    19
# 25            Kevin Murphy          2012                  4  2011-12    21
# 26           Anthony Davis          2012                  1  2011-12    18
# 27           Austin Rivers          2012                  1  2011-12    19
# 28          Andre Drummond          2012                  1  2011-12    18
# 29          Meyers Leonard          2012                  2  2011-12    19
# 30            Robert Sacre          2012                  5  2011-12    22
# 31             Kim English          2012                  4  2011-12    23
# 32         Jared Sullinger          2012                  2  2011-12    19
# 33        Kendall Marshall          2012                  2  2011-12    20
# 34             Perry Jones          2012                  2  2011-12    20
# 35          Terrence Jones          2012                  2  2011-12    20
# 36              Quincy Acy          2012                  4  2011-12    21
# 37             Jae Crowder          2012                  2  2011-12    21
# 38             Royce White          2012                  1  2011-12    20
# 39           Bernard James          2012                  2  2011-12    26
# 40         Arnett Moultrie          2012                  3  2011-12    21
# 41           Miles Plumlee          2012                  4  2011-12    23
# 42             Jeremy Lamb          2012                  2  2011-12    19
# 43           Terrence Ross          2012                  2  2011-12    20
# 44         Orlando Johnson          2012                  4  2011-12    22
# 45             Jeff Taylor          2012                  4  2011-12    22
# 46             Will Barton          2012                  2  2011-12    21
# 47        Maurice Harkless          2012                  1  2011-12    18
# 48                Fab Melo          2012                  2  2011-12    21
# 49           Marcus Denmon          2012                  4  2011-12    21
# 50            Dion Waiters          2012                  2  2011-12    20
#
#        College   G    MP   FG   FGA  ...   BLK   TOV   PTS    FG%    3p%  \
# 0     VIRGINIA  32   999  215   382  ...    15    67   575  0.563  0.300
# 1    MARQUETTE  34  1120  210   470  ...     4    80   623  0.447  0.385
# 2     SYRACUSE  37  1192  164   390  ...    23    55   496  0.421  0.345
# 3     KENTUCKY  40  1303  145   352  ...    11   109   401  0.412  0.325
# 4    NORFOLKST  36  1125  205   358  ...    97    95   572  0.573  0.188
# 5          LSU  33   990  158   320  ...    43    57   426  0.494  0.250
# 6   WASHINGTON  35  1062  198   447  ...    13   132   559  0.443  0.161
# 7       PURDUE  35  1128  194   465  ...    42    32   573  0.417  0.383
# 8      FLORIDA  37  1267  175   393  ...    31    79   546  0.445  0.339
# 9      WEBERST  32  1105  231   495  ...     7    74   784  0.467  0.409
# 10      KANSAS  39  1242  261   517  ...    34   104   692  0.505  0.500
# 11         UNC  38  1070  220   398  ...    58    73   621  0.553    NaN
# 12  MICHIGANST  37  1229  212   472  ...    35   112   601  0.449  0.388
# 13         UNC  35  1019  205   410  ...   101    45   479  0.500    NaN
# 14    KENTUCKY  40  1043  143   302  ...    13    58   397  0.474  0.376
# 15    OREGONST  36  1245  198   440  ...    15   102   645  0.450  0.338
# 16    KENTUCKY  40  1245  160   326  ...    37    87   476  0.491  0.255
# 17     TEXASAM  20   575  102   246  ...     5    43   263  0.415  0.260
# 18      KANSAS  39  1303  226   474  ...     6   138   647  0.477  0.382
# 19    KENTUCKY  40  1249  175   369  ...     2    44   549  0.474  0.466
# 20       VANDY  26   603   89   165  ...    52    58   262  0.539    NaN
# 21     STBONNY  32   962  220   385  ...    63    80   591  0.571  0.434
# 22      BAYLOR  37   903  138   309  ...    24    66   393  0.447  0.348
# 23       VANDY  35  1177  217   458  ...    11    55   696  0.474  0.439
# 24         UNC  38  1111  229   521  ...    13    74   648  0.440  0.358
# 25      TNTECH  33  1139  239   538  ...     7   108   681  0.444  0.416
# 26    KENTUCKY  40  1281  210   337  ...   186    41   567  0.623  0.150
# 27        DUKE  34  1129  174   402  ...     1    79   527  0.433  0.365
# 28       UCONN  34   967  157   292  ...    92    52   340  0.538  0.000
# 29    ILLINOIS  32  1018  170   291  ...    60    68   434  0.584  0.091
# 30     GONZAGA  33   868  117   229  ...    47    60   384  0.511  0.000
# 31    MISSOURI  35  1175  171   328  ...    10    59   507  0.521  0.459
# 32      OHIOST  37  1123  228   439  ...    39    71   647  0.519  0.400
# 33         UNC  36  1189  105   225  ...     6   101   293  0.467  0.354
# 34      BAYLOR  33  1013  182   364  ...    20    56   445  0.500  0.303
# 35    KENTUCKY  38  1115  177   354  ...    68    62   469  0.500  0.327
# 36      BAYLOR  38  1130  158   274  ...    70    71   455  0.577  0.600
# 37   MARQUETTE  35  1153  217   436  ...    35    44   614  0.498  0.345
# 38      IOWAST  34  1072  175   328  ...    32   130   456  0.534  0.333
# 39   FLORIDAST  35   979  157   259  ...    82    73   378  0.606    NaN
# 40      MISSST  30  1073  180   328  ...    23    73   492  0.549  0.444
# 41        DUKE  34   697   89   146  ...    32    42   226  0.610    NaN
# 42       UCONN  34  1266  217   454  ...    21    68   603  0.478  0.336
# 43  WASHINGTON  35  1088  215   470  ...    33    70   574  0.457  0.371
# 44        UCSB  31  1067  207   459  ...    23    76   611  0.451  0.427
# 45       VANDY  36  1157  210   426  ...    16    79   581  0.493  0.423
# 46     MEMPHIS  35  1236  230   452  ...    25    75   631  0.509  0.346
# 47     STJOHNS  32  1155  193   427  ...    45    80   497  0.452  0.215
# 48    SYRACUSE  30   763   98   173  ...    88    43   234  0.566    NaN
# 49    MISSOURI  35  1212  200   435  ...     1    41   619  0.460  0.407
# 50    SYRACUSE  37   891  170   357  ...    12    48   467  0.476  0.363
#
#       FT%   PG_MP   PG_PTS   PG_TRB   PG_AST
# 0   0.808    31.2     18.0      8.3      1.2
# 1   0.764    32.9     18.3      3.5      2.7
# 2   0.745    32.2     13.4      4.7      1.5
# 3   0.714    32.6     10.0      2.5      4.8
# 4   0.696    31.3     15.9     10.3      1.4
# 5   0.781    30.0     12.9      7.2      0.9
# 6   0.583    30.3     16.0      5.0      3.7
# 7   0.825    32.2     16.4      7.2      1.9
# 8   0.769    34.2     14.8      6.7      2.2
# 9   0.887    34.5     24.5      5.0      4.0
# 10  0.682    31.8     17.7     11.9      1.8
# 11  0.808    28.2     16.3      9.6      0.9
# 12  0.723    33.2     16.2     10.6      3.8
# 13  0.511    29.1     13.7      9.9      1.3
# 14  0.797    26.1      9.9      2.8      2.1
# 15  0.737    34.6     17.9      3.8      2.8
# 16  0.745    31.1     11.9      7.4      1.9
# 17  0.750    28.8     13.2      5.0      2.3
# 18  0.688    33.4     16.6      2.3      4.8
# 19  0.826    31.2     13.7      2.7      1.5
# 20  0.604    23.2     10.1      5.9      0.3
# 21  0.776    30.1     18.5      8.4      1.0
# 22  0.816    24.4     10.6      4.9      1.4
# 23  0.837    33.6     19.9      2.9      1.2
# 24  0.723    29.2     17.1      5.2      1.1
# 25  0.721    34.5     20.6      5.2      2.3
# 26  0.709    32.0     14.2     10.4      1.3
# 27  0.658    33.2     15.5      3.4      2.1
# 28  0.295    28.4     10.0      7.6      0.4
# 29  0.732    31.8     13.6      8.2      1.3
# 30  0.761    26.3     11.6      6.3      0.7
# 31  0.725    33.6     14.5      4.2      1.6
# 32  0.768    30.4     17.5      9.2      1.2
# 33  0.696    33.0      8.1      2.6      9.8
# 34  0.696    30.7     13.5      7.6      1.3
# 35  0.627    29.3     12.3      7.2      1.3
# 36  0.782    29.7     12.0      7.4      1.0
# 37  0.735    32.9     17.5      8.4      2.1
# 38  0.498    31.5     13.4      9.3      5.0
# 39  0.552    28.0     10.8      8.1      0.5
# 40  0.780    35.8     16.4     10.5      1.2
# 41  0.632    20.5      6.6      7.1      0.5
# 42  0.810    37.2     17.7      4.9      1.7
# 43  0.766    31.1     16.4      6.4      1.4
# 44  0.698    34.4     19.7      5.8      2.9
# 45  0.605    32.1     16.1      5.6      1.7
# 46  0.749    35.3     18.0      8.0      2.9
# 47  0.676    36.1     15.5      8.6      1.5
# 48  0.633    25.4      7.8      5.8      0.7
# 49  0.896    34.6     17.7      5.0      2.1
# 50  0.729    24.1     12.6      2.3      2.5
#
# [51 rows x 28 columns]

# %% [markdown]
# # Avg. of 2012-13 to 2016-17

# %%
names = list(draft2012['Name'][1:])
namenyear = draft2012[['Name', ' Years in College']][1:] 
namenyear = namenyear.sort_values('Name')
namenyear = namenyear.reset_index()
namenyear = namenyear.drop('index', 1)

#------------------------------------------------------------

n1617 = []
for i in range(len(data1617['Player'])):
    for j in range(len(names)):
        if data1617['Player'][i] == names[j]:
            n1617.append(names[j])       
n1617 = list(set(n1617))

f1617 = pd.DataFrame(index=range(len(n1617)),columns=data1617.columns)

for i in range(len(n1617)):

    for word in f1617.columns:

         f1617[word][i] = data1617.loc[data1617['Player'] == n1617[i]][word].values[0]

#------------------------------------------------------------

n1516 = []
for i in range(len(data1516['Player'])):
    for j in range(len(names)):
        if data1516['Player'][i] == names[j]:
            n1516.append(names[j])       
n1516 = list(set(n1516))

f1516 = pd.DataFrame(index=range(len(n1516)),columns=data1516.columns)

for i in range(len(n1516)):

    for word in f1516.columns:

         f1516[word][i] = data1516.loc[data1516['Player'] == n1516[i]][word].values[0]

#------------------------------------------------------------

n1415 = []
for i in range(len(data1415['Player'])):
    for j in range(len(names)):
        if data1415['Player'][i] == names[j]:
            n1415.append(names[j])       
n1415 = list(set(n1415))

f1415 = pd.DataFrame(index=range(len(n1415)),columns=data1415.columns)

for i in range(len(n1415)):

    for word in f1415.columns:

         f1415[word][i] = data1415.loc[data1415['Player'] == n1415[i]][word].values[0]
                       
#------------------------------------------------------------

n1314 = []
for i in range(len(data1314['Player'])):
    for j in range(len(names)):
        if data1314['Player'][i] == names[j]:
            n1314.append(names[j])       
n1314 = list(set(n1314)) 

f1314 = pd.DataFrame(index=range(len(n1314)),columns=data1314.columns)

for i in range(len(n1314)):

    for word in f1314.columns:

         f1314[word][i] = data1314.loc[data1314['Player'] == n1314[i]][word].values[0]            
        
#------------------------------------------------------------

n1213 = []
for i in range(len(data1213['Player'])):
    for j in range(len(names)):
        if data1213['Player'][i] == names[j]:
            n1213.append(names[j])       
n1213 = list(set(n1213)) 

f1213 = pd.DataFrame(index=range(len(n1213)),columns=data1213.columns)

for i in range(len(n1213)):

    for word in f1213.columns:

         f1213[word][i] = data1213.loc[data1213['Player'] == n1213[i]][word].values[0] 
            
#------------------------------------------------------------

final = f1617.append([f1415, f1314, f1213, f1516])
final = final.reset_index()
final.drop(['index'], axis=1, inplace=True)

final['Age']= final['Age'].astype('float64')
final['G']= final['G'].astype('float64')
final['GS']= final['GS'].astype('float64')
final['MP']= final['MP'].astype('float64')
final['FG']= final['FG'].astype('float64')
final['FGA']= final['FGA'].astype('float64')
final['FG%']= final['FG%'].astype('float64')
final['3P']= final['3P'].astype('float64')
final['3PA']= final['3PA'].astype('float64')
final['3P%']= final['3P%'].astype('float64')
final['2P']= final['2P'].astype('float64')
final['2PA']= final['2PA'].astype('float64')
final['2P%']= final['2P%'].astype('float64')
final['eFG%']= final['eFG%'].astype('float64')
final['FT']= final['FT'].astype('float64')
final['FTA']= final['FTA'].astype('float64')
final['FT%']= final['FT%'].astype('float64')
final['ORB']= final['ORB'].astype('float64')
final['DRB']= final['DRB'].astype('float64')
final['TRB']= final['TRB'].astype('float64')
final['AST']= final['AST'].astype('float64') 
final['STL']= final['STL'].astype('float64')
final['BLK']= final['BLK'].astype('float64')
final['TOV']= final['TOV'].astype('float64')
final['PF']= final['PF'].astype('float64')
final['PS/G']= final['PS/G'].astype('float64')

finaldata = final.groupby('Player', as_index=False).mean()
finaldata.insert(1, "Years in College", namenyear[' Years in College']) 
finaldata['Years in College'] = 0

finaldata = finaldata[['Player', 'Years in College', 'Age', 'G', 'GS', 'MP', 'FG', 'FGA',
       'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA',
       'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PS/G']]

# %%
x = []
for i in range(len(finaldata['Player'])):
    for j in range(len(n1617)):
        if finaldata['Player'][i] == n1617[j]:
            x.append(n1617[j])       
f = list(set(x))

test = finaldata

test = test[test['Player'].isin(f)].reset_index().drop('index', 1)

test.to_csv('Desktop/finaldata/2012draft.csv', sep='\t', encoding='utf-8')
test
# Out:
#                     Player  Years in College        Age          G    GS  \
# 0           Andre Drummond                 0  21.000000  77.000000  67.0
# 1         Andrew Nicholson                 0  25.000000  57.000000   7.2
# 2            Anthony Davis                 0  21.000000  67.000000  66.0
# 3            Austin Rivers                 0  22.000000  69.400000  14.2
