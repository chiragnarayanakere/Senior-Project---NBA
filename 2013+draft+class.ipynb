# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.plotly as py
import warnings
import xgboost as xgb
warnings.filterwarnings('ignore')

# %% [markdown]
# # 2013 draft class

# %%
data1718 = pd.read_csv('Downloads/NBA Player Stats - Regular Stats 2017-2018.csv')
data1718.drop(['Tm', 'Rk'], axis=1, inplace=True)
data1617 = pd.read_csv('Downloads/NBA Player Stats - Regular Stats 2016-2017.csv')
data1617.drop(['Tm', 'Rk'], axis=1, inplace=True)
data1516 = pd.read_csv('Downloads/NBA Player Stats - Regular Stats 2015-2016.csv')
data1516.drop(['Tm', 'Rk'], axis=1, inplace=True)
data1415 = pd.read_csv('Downloads/NBA Player Stats - Regular Stats 2014-2015.csv')
data1415.drop(['Tm', 'Rk'], axis=1, inplace=True)
data1314 = pd.read_csv('Downloads/NBA Player Stats - Regular Stats 2013-2014.csv')
data1314.drop(['Tm', 'Rk'], axis=1, inplace=True)
data1718.head()
# Out:
#           Player         ID  Age   G  GS    MP   FG  FGA    FG%   3P  ...  \
# 0   Alex Abrines  abrinal01   24  75   8  15.1  1.5  3.9  0.395  1.1  ...
# 1     Quincy Acy    acyqu01   27  70   8  19.4  1.9  5.2  0.356  1.5  ...
# 2   Steven Adams  adamsst01   24  76  76  32.7  5.9  9.4  0.629  0.0  ...
# 3    Bam Adebayo  adebaba01   20  69  19  19.8  2.5  4.9  0.512  0.0  ...
# 4  Arron Afflalo  afflaar01   32  53   3  12.9  1.2  3.1  0.401  0.5  ...
#
#      FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF  PS/G
# 0  0.848  0.3  1.2  1.5  0.4  0.5  0.1  0.3  1.7   4.7
# 1  0.817  0.6  3.1  3.7  0.8  0.5  0.4  0.9  2.1   5.9
# 2  0.559  5.1  4.0  9.0  1.2  1.2  1.0  1.7  2.8  13.9
# 3  0.721  1.7  3.8  5.5  1.5  0.5  0.6  1.0  2.0   6.9
# 4  0.846  0.1  1.2  1.2  0.6  0.1  0.2  0.4  1.1   3.4
#
# [5 rows x 28 columns]

# %% [markdown]
# # College data

# %%
draft2013 = pd.read_csv('Downloads/csvfiles/2013_class_urls.csv')
draft2013.columns
draft2013
# Out:
#                         Name   Draft Class   Years in College   Season   Age  \
# 0               Nate Wolters          2013                  4  2012-13    21
# 1              Lorenzo Brown          2013                  3  2012-13    22
# 2               Gorgui Dieng          2013                  3  2012-13    23
# 3              Mason Plumlee          2013                  4  2012-13    22
# 4                Peyton Siva          2013                  4  2012-13    22
# 5               Shane Larkin          2013                  2  2012-13    20
# 6                Otto Porter          2013                  2  2012-13    19
# 7           Shabazz Muhammad          2013                  1  2012-13    20
# 8                   Alex Len          2013                  2  2012-13    19
# 9               Nerlens Noel          2013                  1  2012-13    18
# 10  Kentavious Caldwell-Pope          2013                  2  2012-13    19
# 11               Erik Murphy          2013                  4  2012-13    22
# 12              Solomon Hill          2013                  4  2012-13    21
# 13            Arsalan Kazemi          2013                  4  2012-13    22
# 14               CJ McCollum          2013                  4  2012-13    21
# 15             Tony Mitchell          2013                  2  2012-13    20
# 16               Jeff Withey          2013                  4  2012-13    22
# 17              Alex Oriakhi          2013                  4  2012-13    22
# 18              Kelly Olynyk          2013                  3  2012-13    21
# 19              Mike Muscala          2013                  4  2012-13    21
# 20              Ray McCallum          2013                  3  2012-13    21
# 21            Victor Oladipo          2013                  3  2012-13    20
# 22            Reggie Bullock          2013                  3  2012-13    21
# 23                 Glen Rice          2013                  3  2011-12    21
# 24              Tim Hardaway          2013                  3  2012-13    20
# 25           Anthony Bennett          2013                  1  2012-13    19
# 26            Archie Goodwin          2013                  1  2012-13    18
# 27               Cody Zeller          2013                  2  2012-13    20
# 28            Deshaun Thomas          2013                  3  2012-13    21
# 29              Steven Adams          2013                  1  2012-13    19
# 30             Isaiah Canaan          2013                  4  2012-13    21
# 31           Jamaal Franklin          2013                  3  2012-13    21
# 32                Ryan Kelly          2013                  4  2012-13    21
# 33             Carrick Felix          2013                  3  2012-13    22
# 34                Trey Burke          2013                  2  2012-13    20
# 35            Andre Roberson          2013                  3  2012-13    21
# 36             Grant Jerrett          2013                  1  2012-13    19
# 37              Ben McLemore          2013                  1  2012-13    19
# 38            Pierre Jackson          2013                  2  2012-13    21
# 39   Michael Carter-Williams          2013                  2  2012-13    21
# 40            Colton Iverson          2013                  4  2012-13    23
# 41              Allen Crabbe          2013                  3  2012-13    20
# 42               Erick Green          2013                  4  2012-13    21
# 43                Tony Snell          2013                  3  2012-13    21
#
#        College   G    MP   FG   FGA  ...   BLK   TOV   PTS    FG%    3p%  \
# 0    SDAKOTAST  33  1256  242   499  ...     4    77   735  0.485  0.379
# 1      NCSTATE  33  1129  140   334  ...    19   114   408  0.419  0.263
# 2   LOUISVILLE  33  1026  125   234  ...    83    59   323  0.534    NaN
# 3         DUKE  36  1248  221   369  ...    52   103   615  0.599    NaN
# 4   LOUISVILLE  40  1247  139   344  ...     6   106   401  0.404  0.288
# 5      MIAMIFL  36  1311  183   382  ...     4    82   522  0.479  0.406
# 6   GEORGETOWN  31  1097  168   350  ...    28    47   501  0.480  0.422
# 7         UCLA  32   987  202   456  ...     4    51   572  0.443  0.377
# 8     MARYLAND  38  1004  173   324  ...    78    60   452  0.534  0.125
# 9     KENTUCKY  24   765   98   166  ...   106    45   251  0.590    NaN
# 10     GEORGIA  32  1086  186   430  ...    17    64   591  0.433  0.373
# 11     FLORIDA  36   952  164   318  ...    25    51   440  0.516  0.453
# 12     ARIZONA  35  1154  158   345  ...    20    77   468  0.458  0.390
# 13      OREGON  35  1016  113   190  ...    23    52   328  0.595  0.000
# 14      LEHIGH  12   372   96   194  ...     4    32   287  0.495  0.516
# 15      NTEXAS  32  1037  140   318  ...    87    78   416  0.440  0.300
# 16      KANSAS  37  1144  185   318  ...   146    73   508  0.582  1.000
# 17    MISSOURI  34   878  138   216  ...    54    47   382  0.639    NaN
# 18     GONZAGA  32   845  215   342  ...    36    77   571  0.629  0.300
# 19    BUCKNELL  34  1079  227   446  ...    80    58   637  0.509  0.250
# 20     DETROIT  33  1208  214   436  ...    20    68   617  0.491  0.323
# 21     INDIANA  36  1021  182   304  ...    28    83   491  0.599  0.441
# 22         UNC  35  1100  172   356  ...    10    43   488  0.483  0.436
# 23      GATECH  21   628  102   223  ...    18    48   274  0.457  0.333
# 24    MICHIGAN  38  1324  201   460  ...    17    71   552  0.437  0.374
# 25        UNLV  35   950  202   379  ...    43    65   564  0.533  0.375
# 26    KENTUCKY  33  1048  157   357  ...    15   101   466  0.440  0.266
# 27     INDIANA  36  1062  199   353  ...    45    81   594  0.564  0.000
# 28      OHIOST  37  1309  259   583  ...    11    52   731  0.444  0.344
# 29        PITT  32   749  100   175  ...    65    35   231  0.571    NaN
# 30    MURRAYST  31  1131  215   499  ...     4    98   676  0.431  0.370
# 31  SANDIEGOST  32  1058  165   401  ...    26   110   541  0.411  0.272
# 32        DUKE  23   664   96   212  ...    37    23   296  0.453  0.422
# 33   ARIZONAST  35  1235  189   378  ...    39    70   511  0.500  0.374
# 34    MICHIGAN  39  1378  259   560  ...    20    86   727  0.463  0.384
# 35    COLORADO  31  1036  132   275  ...    41    74   337  0.480  0.328
# 36     ARIZONA  34   606   63   154  ...    33    19   176  0.409  0.405
# 37      KANSAS  37  1191  198   400  ...    25    77   589  0.495  0.420
# 38      BAYLOR  36  1252  216   506  ...     0   122   712  0.427  0.359
# 39    SYRACUSE  40  1409  155   394  ...    20   138   474  0.393  0.294
# 40  COLORADOST  35  1033  183   307  ...    25    69   497  0.596    NaN
# 41  CALIFORNIA  33  1195  215   468  ...    23    83   607  0.459  0.348
# 42      VATECH  32  1166  261   550  ...     6    69   801  0.475  0.389
# 43     NMEXICO  35  1093  144   341  ...    17    72   438  0.422  0.390
#
#       FT%   PG_MP   PG_PTS   PG_TRB   PG_AST
# 0   0.813    38.1     22.3      5.6      5.8
# 1   0.771    34.2     12.4      4.3      7.2
# 2   0.652    31.1      9.8      9.4      2.0
# 3   0.681    34.7     17.1      9.9      1.9
# 4   0.867    31.2     10.0      2.4      5.7
# 5   0.777    36.4     14.5      3.8      4.6
# 6   0.777    35.4     16.2      7.5      2.7
# 7   0.711    30.8     17.9      5.2      0.8
# 8   0.686    26.4     11.9      7.8      1.0
# 9   0.529    31.9     10.5      9.5      1.6
# 10  0.799    33.9     18.5      7.1      1.8
# 11  0.784    26.4     12.2      5.5      1.4
# 12  0.766    33.0     13.4      5.3      2.7
# 13  0.675    29.0      9.4     10.0      1.4
# 14  0.849    31.0     23.9      5.0      2.9
# 15  0.675    32.4     13.0      8.5      0.8
# 16  0.714    30.9     13.7      8.5      0.9
# 17  0.746    25.8     11.2      8.4      0.4
# 18  0.776    26.4     17.8      7.3      1.7
# 19  0.789    31.7     18.7     11.1      2.3
# 20  0.717    36.6     18.7      5.1      4.5
# 21  0.746    28.4     13.6      6.3      2.1
# 22  0.767    31.4     13.9      6.5      2.9
# 23  0.606    29.9     13.0      6.7      2.3
# 24  0.694    34.8     14.5      4.7      2.4
# 25  0.701    27.1     16.1      8.1      1.0
# 26  0.637    31.8     14.1      4.6      2.7
# 27  0.757    29.5     16.5      8.0      1.3
# 28  0.834    35.4     19.8      5.9      1.3
# 29  0.443    23.4      7.2      6.3      0.6
# 30  0.822    36.5     21.8      3.5      4.3
# 31  0.781    33.1     16.9      9.5      3.3
# 32  0.812    28.9     12.9      5.3      1.7
# 33  0.664    35.3     14.6      8.1      1.6
# 34  0.801    35.3     18.6      3.2      6.7
# 35  0.551    33.4     10.9     11.2      1.4
# 36  0.818    17.8      5.2      3.6      0.5
# 37  0.870    32.2     15.9      5.2      2.0
# 38  0.800    34.8     19.8      3.8      7.1
# 39  0.694    35.2     11.9      5.0      7.3
# 40  0.590    29.5     14.2      9.8      1.3
# 41  0.813    36.2     18.4      6.1      2.6
# 42  0.816    36.4     25.0      4.0      3.8
# 43  0.843    31.2     12.5      2.6      2.9
#
# [44 rows x 28 columns]

# %% [markdown]
# # Avg. of 2013-14 to 2017-18

# %%
names = list(draft2013['Name'][1:])
namenyear = draft2013[['Name', ' Years in College']][1:] 
namenyear = namenyear.sort_values('Name')
namenyear = namenyear.reset_index()
namenyear = namenyear.drop('index', 1)

#------------------------------------------------------------

n1718 = []
for i in range(len(data1718['Player'])):
    for j in range(len(names)):
        if data1718['Player'][i] == names[j]:
            n1718.append(names[j])       
n1718 = list(set(n1718))

f1718 = pd.DataFrame(index=range(len(n1718)),columns=data1718.columns)

for i in range(len(n1718)):

    for word in f1718.columns:

         f1718[word][i] = data1718.loc[data1718['Player'] == n1718[i]][word].values[0]

#------------------------------------------------------------

n1617 = []
for i in range(len(data1617['Player'])):
    for j in range(len(names)):
        if data1617['Player'][i] == names[j]:
            n1617.append(names[j])       
n1617 = list(set(n1617))

f1617 = pd.DataFrame(index=range(len(n1617)),columns=data1617.columns)

for i in range(len(n1617)):

    for word in f1617.columns:

         f1617[word][i] = data1617.loc[data1617['Player'] == n1617[i]][word].values[0]

#------------------------------------------------------------

n1516 = []
for i in range(len(data1516['Player'])):
    for j in range(len(names)):
        if data1516['Player'][i] == names[j]:
            n1516.append(names[j])       
n1516 = list(set(n1516))

f1516 = pd.DataFrame(index=range(len(n1516)),columns=data1516.columns)

for i in range(len(n1516)):

    for word in f1516.columns:

         f1516[word][i] = data1516.loc[data1516['Player'] == n1516[i]][word].values[0]

#------------------------------------------------------------

n1415 = []
for i in range(len(data1415['Player'])):
    for j in range(len(names)):
        if data1415['Player'][i] == names[j]:
            n1415.append(names[j])       
n1415 = list(set(n1415))

f1415 = pd.DataFrame(index=range(len(n1415)),columns=data1415.columns)

for i in range(len(n1415)):

    for word in f1415.columns:

         f1415[word][i] = data1415.loc[data1415['Player'] == n1415[i]][word].values[0]
                       
#------------------------------------------------------------

n1314 = []
for i in range(len(data1314['Player'])):
    for j in range(len(names)):
        if data1314['Player'][i] == names[j]:
            n1314.append(names[j])       
n1314 = list(set(n1314)) 

f1314 = pd.DataFrame(index=range(len(n1314)),columns=data1314.columns)

for i in range(len(n1314)):

    for word in f1314.columns:

         f1314[word][i] = data1314.loc[data1314['Player'] == n1314[i]][word].values[0]            
        
#------------------------------------------------------------


final = f1718.append([f1415, f1314, f1617, f1516])
final = final.reset_index()
final.drop(['index'], axis=1, inplace=True)

final['Age']= final['Age'].astype('float64')
final['G']= final['G'].astype('float64')
final['GS']= final['GS'].astype('float64')
final['MP']= final['MP'].astype('float64')
final['FG']= final['FG'].astype('float64')
final['FGA']= final['FGA'].astype('float64')
final['FG%']= final['FG%'].astype('float64')
final['3P']= final['3P'].astype('float64')
final['3PA']= final['3PA'].astype('float64')
final['3P%']= final['3P%'].astype('float64')
final['2P']= final['2P'].astype('float64')
final['2PA']= final['2PA'].astype('float64')
final['2P%']= final['2P%'].astype('float64')
final['eFG%']= final['eFG%'].astype('float64')
final['FT']= final['FT'].astype('float64')
final['FTA']= final['FTA'].astype('float64')
final['FT%']= final['FT%'].astype('float64')
final['ORB']= final['ORB'].astype('float64')
final['DRB']= final['DRB'].astype('float64')
final['TRB']= final['TRB'].astype('float64')
final['AST']= final['AST'].astype('float64') 
final['STL']= final['STL'].astype('float64')
final['BLK']= final['BLK'].astype('float64')
final['TOV']= final['TOV'].astype('float64')
final['PF']= final['PF'].astype('float64')
final['PS/G']= final['PS/G'].astype('float64')

finaldata = final.groupby('Player', as_index=False).mean()
finaldata.insert(1, "Years in College", namenyear[' Years in College']) 
finaldata['Years in College'] = 0

finaldata = finaldata[['Player', 'Years in College', 'Age', 'G', 'GS', 'MP', 'FG', 'FGA',
       'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA',
       'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PS/G']]

# %%
x = []
for i in range(len(finaldata['Player'])):
    for j in range(len(n1718)):
        if finaldata['Player'][i] == n1718[j]:
            x.append(n1718[j])       
f = list(set(x))

test = finaldata

test = test[test['Player'].isin(f)].reset_index().drop('index', 1)

test.to_csv('Desktop/finaldata/2013draft.csv', sep='\t', encoding='utf-8')
test
# Out:
#                       Player  Years in College    Age      G     GS      MP  \
# 0                   Alex Len                 0  22.00  67.00  28.00  18.880
# 1               Allen Crabbe                 0  23.00  60.20  18.40  20.780
# 2             Andre Roberson                 0  24.00  59.00  53.80  21.620
# 3               Ben McLemore                 0  22.00  69.80  46.60  23.860
# 4                CJ McCollum                 0  24.00  68.20  48.80  26.820
# 5                Cody Zeller                 0  23.00  62.40  33.20  22.480
# 6               Gorgui Dieng                 0  26.00  75.20  37.00  24.000
# 7              Isaiah Canaan                 0  24.00  41.00  12.20  18.660
# 8                Jeff Withey                 0  25.00  41.20   3.00   8.900
# 9               Kelly Olynyk                 0  24.00  70.80  11.60  21.260
# 10  Kentavious Caldwell-Pope                 0  22.00  77.60  69.60  30.900
# 11             Lorenzo Brown                 0  24.75  19.25   1.75  11.250
# 12             Mason Plumlee                 0  25.00  77.80  47.80  22.160
# 13   Michael Carter-Williams                 0  24.00  57.40  38.20  26.500
# 14              Mike Muscala                 0  24.00  48.60   3.60  14.100
# 15              Nerlens Noel                 0  21.50  55.75  39.50  24.075
# 16               Otto Porter                 0  22.00  68.60  48.60  24.500
# 17            Reggie Bullock                 0  24.00  41.80  11.80  14.640
# 18          Shabazz Muhammad                 0  23.00  55.60   3.20  16.040
# 19              Shane Larkin                 0  22.75  64.00  10.25  17.875
# 20              Solomon Hill                 0  24.00  52.20  30.60  19.420
# 21              Steven Adams                 0  22.00  77.40  64.60  25.580
# 22              Tim Hardaway                 0  23.00  67.60  23.20  24.880
# 23                Tony Snell                 0  24.00  73.60  41.20  22.500
# 24                Trey Burke                 0  23.00  60.60  24.00  23.560
# 25            Victor Oladipo                 0  23.00  73.20  61.80  33.400
#
#       FG     FGA      FG%     3P  ...      FT%    ORB   DRB    TRB    AST  \
# 0   2.58   5.300  0.48320  0.000  ...  0.69600  1.960  4.16  6.140  0.720
# 1   2.82   6.560  0.42200  1.360  ...  0.81320  0.220  2.12  2.380  1.040
# 2   1.80   3.740  0.48800  0.340  ...  0.50580  1.200  2.72  3.920  0.860
# 3   3.24   7.740  0.41860  1.200  ...  0.78320  0.480  2.04  2.520  1.120
# 4   5.88  13.020  0.44460  1.760  ...  0.79000  0.500  2.24  2.720  2.600
# 5   2.96   5.740  0.50640  0.020  ...  0.73100  1.820  3.84  5.640  1.240
# 6   3.12   6.180  0.50340  0.100  ...  0.76660  2.060  4.52  6.580  1.440
# 7   2.42   6.540  0.36920  1.340  ...  0.83700  0.300  1.48  1.780  1.920
# 8   1.12   2.180  0.49620  0.040  ...  0.67420  0.720  1.50  2.240  0.240
# 9   3.72   7.760  0.48100  1.020  ...  0.74940  1.320  3.56  4.900  1.900
# 10  4.38  10.660  0.40840  1.640  ...  0.77960  0.700  2.74  3.460  1.700
# 11  1.20   3.250  0.36500  0.125  ...  0.76850  0.225  1.15  1.375  1.750
# 12  3.32   5.860  0.57700  0.000  ...  0.56020  1.980  4.26  6.240  2.000
# 13  4.04  10.100  0.39020  0.440  ...  0.72480  0.900  3.64  4.540  4.580
# 14  2.02   4.140  0.48740  0.460  ...  0.87200  1.000  2.08  3.060  0.800
# 15  3.50   6.775  0.52550  0.000  ...  0.66075  2.050  4.85  6.900  1.300
# 16  3.76   7.780  0.46100  1.120  ...  0.76300  1.120  3.40  4.500  1.260
# 17  1.78   4.040  0.40960  0.880  ...  0.77760  0.300  1.50  1.820  0.720
# 18  3.24   6.840  0.46860  0.380  ...  0.73700  1.020  1.62  2.680  0.540
# 19  2.00   4.775  0.40975  0.475  ...  0.76575  0.325  1.45  1.800  2.675
# 20  1.70   4.400  0.38380  0.600  ...  0.76860  0.660  2.36  2.980  1.440
# 21  3.62   6.180  0.57200  0.000  ...  0.56700  3.180  3.80  7.000  0.900
# 22  4.28  10.080  0.42460  1.680  ...  0.82080  0.300  2.14  2.420  1.720
# 23  2.30   5.480  0.41500  1.160  ...  0.81340  0.260  2.16  2.420  1.060
# 24  4.26  10.220  0.42380  1.240  ...  0.77600  0.340  1.70  2.060  3.760
# 25  6.40  14.420  0.44240  1.500  ...  0.79620  0.620  3.92  4.520  3.800
#
#       STL    BLK    TOV     PF    PS/G
# 0   0.400  0.980  1.200  2.600   6.760
# 1   0.520  0.280  0.620  1.800   7.940
# 2   0.900  0.640  0.620  2.160   4.340
# 3   0.680  0.180  1.300  2.320   8.860
# 4   0.840  0.280  1.660  1.920  15.460
# 5   0.640  0.740  1.000  2.580   7.940
# 6   0.860  1.080  1.260  2.420   8.100
# 7   0.620  0.120  1.100  1.460   7.600
# 8   0.220  0.660  0.320  0.960   2.960
# 9   0.740  0.480  1.460  2.920   9.900
# 10  1.200  0.200  1.060  1.920  12.060
# 11  0.575  0.100  0.725  0.850   2.875
# 12  0.780  0.960  1.480  2.660   8.540
# 13  1.340  0.560  2.520  2.540  10.800
# 14  0.360  0.520  0.640  1.380   5.160
# 15  1.475  1.275  1.550  2.550   8.525
# 16  1.040  0.360  0.720  1.720   9.560
# 17  0.440  0.100  0.360  0.740   4.740
# 18  0.300  0.100  0.600  0.960   8.560
# 19  0.850  0.075  1.100  1.425   5.150
# 20  0.620  0.200  0.860  1.640   4.840
# 21  0.760  1.000  1.380  2.740   8.840
# 22  0.600  0.160  1.040  1.580  12.020
# 23  0.480  0.260  0.660  1.400   6.240
# 24  0.580  0.120  1.360  1.420  10.800
# 25  1.700  0.540  2.560  2.440  17.340
#
# [26 rows x 28 columns]
