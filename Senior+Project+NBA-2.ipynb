# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.plotly as py
import warnings
import xgboost as xgb
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2017-2018 data

# %%
data = pd.read_csv('Desktop/senior_project/2017-2018nba.csv')
data1718 = data.drop(['Rk'], axis=1)

#Removing duplicates, for players that got traded I'm going to get the average of all their stats so we can
#get a more comprehensive picture
data1718_final = data1718.groupby('Player', as_index=False).first()
data1718_final.head()
# Out:
#                      Player Pos  Age   Tm   G  GS    MP   FG  FGA    FG%  \
# 0    Aaron Brooks\brookaa01  PG   33  MIN  32   1   189   28   69  0.406
# 1    Aaron Gordon\gordoaa01  PF   22  ORL  58  57  1909  375  865  0.434
# 2  Aaron Harrison\harriaa01  SG   23  DAL   9   3   233   19   69  0.275
# 3   Aaron Jackson\jacksaa01  PG   31  HOU   1   0    35    3    9  0.333
# 4     Abdel Nader\naderab01  SF   24  BOS  48   1   522   50  149  0.336
#
#    ...     FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  ...   0.727    7   10   17   20    6    0   11   28    75
# 1  ...   0.698   87  370  457  136   59   45  107  111  1022
# 2  ...   0.765    4   20   24   11    9    2    3   27    60
# 3  ...   0.500    2    1    3    1    0    0    1    4     8
# 4  ...   0.590   13   58   71   26   15   10   34   45   146
#
# [5 rows x 29 columns]

# %%
target1718 = data1718_final['PTS']
newdata1718 = data1718_final.drop(['PTS', 'Player', 'Pos', 'Tm'], axis=1)

# %%
model1718 = xgb.XGBClassifier()
model1718.fit(newdata1718, target1718)
xgb.plot_importance(model1718, importance_type = 'weight')
plt.show()

# %% [markdown]
# ## 2016-2017 data

# %%
data = pd.read_csv('Desktop/senior_project/2016-2017nba.csv')
data1617 = data.drop(['Rk'], axis=1)

#Removing duplicates, for players that got traded I'm going to get the average of all their stats so we can
#get a more comprehensive picture
data1617_final = data1617.groupby('Player', as_index=False).first()
data1617_final.head()
# Out:
#                      Player Pos  Age   Tm   G  GS    MP   FG  FGA    FG%  \
# 0    A.J. Hammons\hammoaj01   C   24  DAL  22   0   163   17   42  0.405
# 1    Aaron Brooks\brookaa01  PG   32  IND  65   0   894  121  300  0.403
# 2    Aaron Gordon\gordoaa01  SF   21  ORL  80  72  2298  393  865  0.454
# 3  Aaron Harrison\harriaa01  SG   22  CHO   5   0    17    0    4  0.000
# 4   Adreian Payne\paynead01  PF   25  MIN  18   0   135   23   54  0.426
#
#    ...     FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  ...   0.450    8   28   36    4    1   13   10   21    48
# 1  ...   0.800   18   51   69  125   25    9   66   93   322
# 2  ...   0.719  116  289  405  150   65   40   89  172  1019
# 3  ...   0.500    0    3    3    3    0    0    0    2     1
# 4  ...   0.737    9   24   33    7    8    7    8   32    63
#
# [5 rows x 29 columns]

# %%
target1617 = data1617_final['PTS']
newdata1617 = data1617_final.drop(['PTS', 'Player', 'Pos', 'Tm'], axis=1)

# %%
model1617 = xgb.XGBClassifier()
model1617.fit(newdata1617, target1617)
xgb.plot_importance(model1617, importance_type = 'weight')
plt.show()

# %% [markdown]
# ## 2015-2016 data

# %%
data = pd.read_csv('Desktop/senior_project/2015-2016nba.csv')
data1516 = data.drop(['Rk'], axis=1)

#Removing duplicates, for players that got traded I'm going to get the average of all their stats so we can
#get a more comprehensive picture
data1516_final = data1516.groupby('Player', as_index=False).first()
data1516_final.head()
# Out:
#                      Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  \
# 0    Aaron Brooks\brookaa01  PG   31  CHI  69   0  1108  188   469  0.401
# 1    Aaron Gordon\gordoaa01  PF   20  ORL  78  37  1863  274   579  0.473
# 2  Aaron Harrison\harriaa01  SG   21  CHO  21   0    93    5    19  0.263
# 3   Adreian Payne\paynead01  PF   24  MIN  52   2   486   53   145  0.366
# 4      Al Horford\horfoal01   C   29  ATL  82  82  2631  529  1048  0.505
#
#    ...     FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  ...   0.766   21   80  101  180   30   10   82  132   491
# 1  ...   0.668  154  353  507  128   59   55   66  153   719
# 2  ...   0.417    4   11   15    2    6    0    4   10    18
# 3  ...   0.654   20   91  111   29   16   11   36   77   132
# 4  ...   0.798  148  448  596  263   68  121  107  163  1249
#
# [5 rows x 29 columns]

# %%
target1516 = data1516_final['PTS']
newdata1516 = data1516_final.drop(['PTS', 'Player', 'Pos', 'Tm'], axis=1)

# %%
model1516 = xgb.XGBClassifier()
model1516.fit(newdata1516, target1516)
xgb.plot_importance(model1516, importance_type = 'weight')
plt.show()

# %% [markdown]
# ## 2014-2015 data

# %%
data = pd.read_csv('Desktop/senior_project/2014-2015nba.csv')
data1415 = data.drop(['Rk'], axis=1)

#Removing duplicates, for players that got traded I'm going to get the average of all their stats so we can
#get a more comprehensive picture
data1415_final = data1415.groupby('Player', as_index=False).first()
data1415_final.head()
# Out:
#                     Player Pos  Age   Tm   G  GS    MP   FG  FGA    FG%  ...   \
# 0     A.J. Price\priceaj01  PG   28  TOT  26   0   324   51  137  0.372  ...
# 1   Aaron Brooks\brookaa01  PG   30  CHI  82  21  1885  344  817  0.421  ...
# 2   Aaron Gordon\gordoaa01  PF   19  ORL  47   8   797   93  208  0.447  ...
# 3  Adreian Payne\paynead01  PF   23  TOT  32  22   739   91  220  0.414  ...
# 4     Al Horford\horfoal01   C   28  ATL  76  76  2318  519  965  0.538  ...
#
#      FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  0.667    6   26   32   46    7    0   14   15   133
# 1  0.833   32  134  166  261   54   15  157  189   954
# 2  0.721   46  123  169   33   21   22   38   83   243
# 3  0.652   48  114  162   30   19    9   44   88   213
# 4  0.759  131  413  544  244   68   98  100  121  1156
#
# [5 rows x 29 columns]

# %%
target1415 = data1415_final['PTS']
newdata1415 = data1415_final.drop(['PTS', 'Player', 'Pos', 'Tm'], axis=1)

# %%
model1415 = xgb.XGBClassifier()
model1415.fit(newdata1415, target1415)
xgb.plot_importance(model1415, importance_type = 'weight')
plt.show()

# %% [markdown]
# ## 2013-2014 data

# %%
data = pd.read_csv('Desktop/senior_project/2013-2014nba.csv')
data1314 = data.drop(['Rk'], axis=1)

#Removing duplicates, for players that got traded I'm going to get the average of all their stats so we can
#get a more comprehensive picture
data1314_final = data1314.groupby('Player', as_index=False).first()
data1314_final.head()
# Out:
#                     Player Pos  Age   Tm   G  GS    MP   FG  FGA    FG% ...   \
# 0     A.J. Price\priceaj01  SG   27  MIN  28   0    99   19   46  0.413 ...
# 1   Aaron Brooks\brookaa01  PG   29  TOT  72  12  1557  233  581  0.401 ...
# 2      Aaron Gray\grayaa01   C   29  TOT  37   6   355   27   61  0.443 ...
# 3  Adonis Thomas\thomaad01  SF   20  TOT   6   1    37    6   14  0.429 ...
# 4  Al Harrington\harrial01  PF   33  WAS  34   0   511   82  207  0.396 ...
#
#      FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF  PTS
# 0  0.000    1    9   10   13    1    0    7    5   44
# 1  0.874   43   97  140  233   52   13  117  146  645
# 2  0.550   42   69  111   22   10    8   31   64   65
# 3  1.000    0    3    3    3    0    0    1    6   14
# 4  0.771   15   65   80   28   14    0   34   72  225
#
# [5 rows x 29 columns]

# %%
target1314 = data1314_final['PTS']
newdata1314 = data1314_final.drop(['PTS', 'Player', 'Pos', 'Tm'], axis=1)

# %%
model1314 = xgb.XGBClassifier()
model1314.fit(newdata1314, target1314)
xgb.plot_importance(model1314, importance_type = 'weight')
plt.show()
